# %%
import csv
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn import cross_validation
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_excel('roads_value.xlsx', sheetname='Sheet1')
df_x = df.drop(2018, axis=1)
df_y = df[2018]
X_train, X_test, Y_train, Y_test = train_test_split(df_x,df_y,test_size=0.2)
model = sm.OLS(Y_train, X_train)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   2018   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.380e+04
# Date:                Wed, 11 Apr 2018   Prob (F-statistic):               0.00
# Time:                        20:05:41   Log-Likelihood:                -3852.5
# No. Observations:                 367   AIC:                             7727.
# Df Residuals:                     356   BIC:                             7770.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 2007           0.0089      0.032      0.273      0.785      -0.055       0.073
# ...

# %%
df2 = pd.read_csv('values_without_unit.csv')
df2 = df2.drop(columns=['Unnamed: 0'])
df_x = df2.drop('2018', axis=1).drop('address',axis=1)
df_y = df2['2018']
X_train, X_test, Y_train, Y_test = train_test_split(df_x,df_y,test_size=0.2)
model = sm.OLS(Y_train, X_train)
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   2018   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 3.942e+05
# Date:                Wed, 11 Apr 2018   Prob (F-statistic):               0.00
# Time:                        20:15:19   Log-Likelihood:                -78038.
# No. Observations:                6896   AIC:                         1.561e+05
# Df Residuals:                    6885   BIC:                         1.562e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 2007           0.0070      0.008      0.864      0.388      -0.009       0.023
# ...

# %%
import shapefile
sf = shapefile.Reader("boston_neighborhood_shapefiles_iq5.shp")
shapes = sf.shapes()

# %%
lst = []
for shp in range(len(shapes)):
    shap = shapes[shp]
    lst.append(shap.points)

#     for i in range(len(shap.points)):
#         print(shap.points[i])
#         for x in range(len(shap.points[i])):
#             print(shap.points[i][x])

# %%
len(lst)
lst[26]
# Out:
# [(800278.7999624461, 2939813.6002891064),
#  (800134.2995952815, 2939797.0002566874),
#  (800065.5001921952, 2939803.4999156),
#  (799967.1004546136, 2939793.8004599363),
#  (799894.700336948, 2939761.2998687774),
#  (799809.2999171913, 2939747.9996985197),
#  (799704.4001926035, 2939738.200177431),
#  (799638.7999301106, 2939711.300296858),
#  (799586.6002313644, 2939698.600519106),
#  (799550.2003697753, 2939669.0999219418),
#  (799504.3999364376, 2939623.3001447767),
#  (799478.1001202762, 2939528.1999412775),
#  (799428.7996939421, 2939439.4999874383),
#  (799382.999916777, 2939363.9000730217),
#  (799356.7004286945, 2939298.3001386076),
#  (799330.3999563605, 2939239.2008473575),
#  (799268.0004748553, 2939095.0003483593),
#  (799241.6996744424, 2939022.9000988603),
#  (799195.9999626875, 2938986.5999746025),
#  (799071.3004089445, 2938947.29985635),
#  (799028.6997723579, 2938934.300538525),
#  (798910.4998775274, 2938894.700552106),
#  (798733.3001006991, 2938848.599922523),
# ...

# %%
num = 0
for nbhd in lst:
    if nbhd[0][0]>-71.039 and nbhd[0][0]<-70.96 and nbhd[0][1]>42.392 and nbhd[0][1]<42.442:
        num+=1
num
# Out:
# 0
