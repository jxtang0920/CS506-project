# %%
import pandas as pd

# %% [markdown]
# ### Read datasets

# %%
#reading datasets
df_mailing = pd.read_excel('2 residential exemption mailing.xlsx', sheetname='Sheet1')
df_mailing = df_mailing.drop(columns=['Unnamed: 2','Unnamed: 9','Unnamed: 13'])
df_rk1 = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Assessors')
df_rk2 = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Resident List')
df_rk1.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_rk2.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_mailing.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
df_mismatch=[]
total0 = 0
for row in df_rk1.itertuples():
    if row.Address_Match == False:
        df_mismatch.append(row)
        total0 += 1
    if row.Address_Match == True:
        total0 += 1
df_mismatch = pd.DataFrame(df_mismatch)

# %%
df_mismatch
# Out:
#       Index  Owners           Parcel_ID Street_Number              Street  \
# 0       NaN     NaN          23-352-39           404       RESERVOIR AVE
# 1       NaN     NaN           21-340-9            36            FENNO ST
# 2       NaN     NaN         26-430E-20            85           GENEVA ST
# 3       NaN     NaN         27-439Q-20            58           SQUIRE RD
# 4       NaN     NaN          10-182-18            80          CALUMET ST
# 5       NaN     NaN          22-383-31            12          FURNESS ST
# 6       NaN     NaN      10-189-22A-9C           350   REVERE BEACH BLVD
# 7       NaN     NaN           7-212-3B           590   REVERE BEACH PKWY
# 8       NaN     NaN            8-129-6            60         THORNTON ST
# 9       NaN     NaN            8-132-6            17           WALNUT PL
# 10      NaN     NaN        2-65-66-4-2             9       PIER VIEW AVE
# 11      NaN     NaN            2-50-15            59         DOLPHIN AVE
# 12      NaN     NaN           8-147-18            37          WALNUT AVE
# 13      NaN     NaN         14-192H-25            33        BICKFORD AVE
# 14      NaN     NaN         14-192K-19            29          DELANO AVE
# 15      NaN     NaN         24-412C-20           152           FENLEY ST
# 16      NaN     NaN        27-447-3-64           175             WARD ST
# 17      NaN     NaN     10-189-43B-423           360   REVERE BEACH BLVD
# 18      NaN     NaN           1-12-37A            58           SUMMER ST
# 19      NaN     NaN            1-16-30           859        WINTHROP AVE
# 20      NaN     NaN           8-148-26           539            BEACH ST
# 21      NaN     NaN     10-189-43B-422           360   REVERE BEACH BLVD
# 22      NaN     NaN           1-34A-3A           205      BELLINGHAM AVE
# 23      NaN     NaN  8-160-161-1C-1514           376           OCEAN AVE
# 24      NaN     NaN         10-185D-11           466           REVERE ST
# 25      NaN     NaN         28-438I-10           141            DERBY RD
# 26      NaN     NaN       18-300-6A-10           100           ATWOOD ST
# 27      NaN     NaN       33-459-3-504           109            SALEM ST
# 28      NaN     NaN         7-110-8A-A            45        FLORENCE AVE
# 29      NaN     NaN     10-189-43B-205           360   REVERE BEACH BLVD
# ...     ...     ...                 ...           ...                 ...
# 3169    NaN     NaN           24-404-4            51            ADAMS ST
# 3170    NaN     NaN             1-30-4           141      BRADSTREET AVE
# 3171    NaN     NaN             1-36-4           135      BELLINGHAM AVE
# 3172    NaN     NaN             8-96-6            12              DIX ST
# 3173    NaN     NaN           10-184-4            41       BEACHLAND AVE
# 3174    NaN     NaN           24-404-3            57            ADAMS ST
# 3175    NaN     NaN             1-7-27          1107        WINTHROP AVE
# 3176    NaN     NaN             2-49-9           128        ATLANTIC AVE
# 3177    NaN     NaN            2-49-10             6            STATE RD
# 3178    NaN     NaN            2-49-11           124        ATLANTIC AVE
# 3179    NaN     NaN            3-40-24            32           CREST AVE
# 3180    NaN     NaN            7-110-1             5        FLORENCE AVE
# 3181    NaN     NaN           15-224-8            12       HARRINGTON ST
# 3182    NaN     NaN           8-146-11           583            BEACH ST
# 3183    NaN     NaN           8-151-13           592            BEACH ST
# 3184    NaN     NaN           8-136-16            54            DEHON ST
# 3185    NaN     NaN          26-400-27           142          LINCOLN ST
# 3186    NaN     NaN      10-189-22A-4F           350   REVERE BEACH BLVD
# 3187    NaN     NaN         14-192K-23            45          DELANO AVE
# 3188    NaN     NaN         27-439V-1A           211          LANTERN RD
# 3189    NaN     NaN         27-439V-5B           237          LANTERN RD
# 3190    NaN     NaN          27-439V-7           249          LANTERN RD
# 3191    NaN     NaN          27-439V-8           259          LANTERN RD
# 3192    NaN     NaN          27-439W-3           216          LANTERN RD
# 3193    NaN     NaN          27-439W-4           230          LANTERN RD
# 3194    NaN     NaN          27-439W-5           242          LANTERN RD
# 3195    NaN     NaN          27-439W-6           256          LANTERN RD
# 3196    NaN     NaN      27-446445F-1B            83             WARD ST
# 3197    NaN     NaN        28-439J1-20           172          LANTERN RD
# 3198    NaN     NaN          22-362-18           150           WARREN ST
#
#      Unit_Number                 Merged                          Owner_1  \
# 0                     404 RESERVOIR AVE                  PAWLOWSKI PAUL
# 1                           36 FENNO ST                  PAWLOWSKI PAUL
# 2                          85 GENEVA ST                 MATTHEWS ROBERT
# 3                          58 SQUIRE RD                     BRADY PETER
# 4                         80 CALUMET ST                LAYAKOUBI BELAID
# 5                         12 FURNESS ST                 ALVINO ERNEST J
# 6            9C   350 REVERE BEACH BLVD                CARDUCCI SUSAN T
# 7                 590 REVERE BEACH PKWY         EXTRA SPACE PROP 76 LLC
# 8                        60 THORNTON ST           RODRIGUES MIGUEL JOSE
# 9                          17 WALNUT PL                  COB REALTY LLC
# 10            2         9 PIER VIEW AVE                    KRAMER NANDA
# 11                       59 DOLPHIN AVE                   DESESA LAURIE
# 12                        37 WALNUT AVE                   DESESA LAURIE
# 13                      33 BICKFORD AVE                       GAO YIFAN
# 14                        29 DELANO AVE                    DODGE JACK P
# 15                        152 FENLEY ST                  DASCOLI ERNEST
# 16           64             175 WARD ST                 WELLS JR ROBERT
# 17          423   360 REVERE BEACH BLVD                 BOUMIL MARCIA M
# 18                         58 SUMMER ST                 GREATHEAD PETER
# 19                     859 WINTHROP AVE                     DELUCA ZELA
# 20                         539 BEACH ST                  BONILLA CARLOS
# 21          422   360 REVERE BEACH BLVD     DEBORAH A REID LIVING TRUST
# 22                   205 BELLINGHAM AVE                   WELCH EMILY R
# 23         1514           376 OCEAN AVE   AZNIV IRREVOCABLE FAM GIFT TR
# 24                        466 REVERE ST                    SAINI GURNAM
# 25                         141 DERBY RD                      KHANDA LLC
# 26           10           100 ATWOOD ST                      KHANDA LLC
# 27          504            109 SALEM ST                   IOVANNA KARLA
# 28            A         45 FLORENCE AVE                     SAINI MOHAN
# 29          205   360 REVERE BEACH BLVD            ABUIRMEILEH YOUNES R
# ...          ...                    ...                              ...
# 3169                        51 ADAMS ST  SALVATORE P FARO REAL ESTATE L
# 3170                 141 BRADSTREET AVE                    FENLON PETER
# 3171                 135 BELLINGHAM AVE                  KONCAR DALIBOR
# 3172                          12 DIX ST                 RUBBICCO DONALD
# 3173                   41 BEACHLAND AVE                 ESCOBAR CLAUDIA
# 3174                        57 ADAMS ST                  FARO SALVATORE
# 3175                  1107 WINTHROP AVE                   SAVARD JOSEPH
# 3176                   128 ATLANTIC AVE                   BARRY MAUREEN
# 3177                         6 STATE RD               POMEROY FRANCIS X
# 3178                   124 ATLANTIC AVE               ROSSI JR EDWARD A
# 3179                       32 CREST AVE               MARTELLI SEBATIAN
# 3180                     5 FLORENCE AVE         FREED DAVID A AKA AARON
# 3181                   12 HARRINGTON ST                      LANE JAMES
# 3182                       583 BEACH ST                   SAVARD JOSEPH
# 3183                       592 BEACH ST              BURROUGHS CONCETTA
# 3184                        54 DEHON ST                 BECKERT ROGER P
# 3185                     142 LINCOLN ST  142 LINCOLN STREET NOMINEE TRU
# 3186         4F   350 REVERE BEACH BLVD      BOVA SALVATORE LIFE ESTATE
# 3187                      45 DELANO AVE                     CAHILL SEAN
# 3188                     211 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3189                     237 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3190                     249 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3191                     259 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3192                     216 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3193                     230 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3194                     242 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3195                     256 LANTERN RD        NORTHGATE APARTMENTS LLC
# 3196                         83 WARD ST     RUMNEY FLATS APARTMENTS LLC
# 3197                     172 LANTERN RD   ANGELINA GAMBARDELLA IRREVOCA
# 3198                      150 WARREN ST                 SOLOMON KERRI A
#
#                               Owner_2                       Owner_3  \
# 0                    MATTHEWS ROBERT
# 1
# 2                     PAWLOWSKI PAUL
# 3                    ANNABELLE BRADY
# 4                     CHERIFI SAADIA
# 5                   ALVINO BERNICE A
# 6
# 7
# 8
# 9             C/O CLIFTON MANAGEMENT
# 10
# 11
# 12
# 13
# 14                    MARTIN PHILLIP
# 15                   THERESA DASCOLI
# 16                     WELLS MARYANN
# 17
# 18                     SHARI M TRAUB
# 19                 C/O JOANNE DUPUIS
# 20                      ALBA BONILLA
# 21            REID DEBORAH A TRUSTEE
# 22                   WELCH BRIGHAM D
# 23         MASEREJIAN JACK K TRUSTEE        NAROIAN SUZY M TRUSTEE
# 24
# 25
# 26
# 27
# 28
# 29
# ...                               ...                           ...
# 3169
# 3170                   JANE S FENLON
# 3171    S HUSANOVIC & I K OSMANCEVIC
# 3172
# 3173
# 3174                   LORRAINE FARO
# 3175              GENEVIEVE B SAVARD
# 3176
# 3177
# 3178
# 3179
# 3180  LAFEYETE MGT GROUP REALTY TRUS
# 3181
# 3182              GENEVIEVE B SAVARD
# 3183                  LISA BURROUGHS
# 3184
# 3185         PABLA GURDEEP S TRUSTEE        DASS JASMINE S TRUSTEE
# 3186  GONZALEZ ANDREA J REMAINDERMAN   BOVA STEPHEN A REMAINDERMAN
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197   GAMBARDELLA ANGELINA, TRUSTEE     ALBEE CHRISTINE L TRUSTEE
# 3198                  FLYNN THOMAS A
#
#          ...          Mailing_City  State          Zip  LUC Not_OO Substring1  \
# 0        ...             ABINGTON     MA        02351   101      X      Trust
# 1        ...             ABINGTON     MA        02351   104      X      Trust
# 2        ...             ABINGTON     MA        02351   104      X      Trust
# 3        ...               ACCORD     MA   02018-0201   105      X      Trust
# 4        ...                ACTON     MA        01720   101      X      Trust
# 5        ...                ACTON     ME        04001   101      X      Trust
# 6        ...              ALAMEDA     CA        94501   102      X      Trust
# 7        ...           ALEXANDRIA     VA        22320    31      X      Trust
# 8        ...             ALLISTON     MA        02134   111      X      Trust
# 9        ...              ALLSTON     MA        02134   112      X      Trust
# 10       ...             AMESBURY     MA        01913   102      X      Trust
# 11       ...             AMESBURY     MA        01913   111      X      Trust
# 12       ...             AMESBURY     MA        01913   112      X      Trust
# 13       ...              AMHERST     MA   01004-0922   101      X      Trust
# 14       ...              AMHERST     NH        03031   101      X      Trust
# 15       ...              ANDOVER     MA        01810   101      X      Trust
# 16       ...              ANDOVER     MA        01810   102      X      Trust
# 17       ...              ANDOVER     MA        01810   102      X      Trust
# 18       ...              ANDOVER     MA        01810   104      X      Trust
# 19       ...              ANDOVER     MA        01810   104      X      Trust
# 20       ...              ANDOVER     MA        01810   105      X      Trust
# 21       ...            ANNAPOLIS     MD        21401   102      X      Trust
# 22       ...         APPLE VALLEY     CA        92308   101      X      Trust
# 23       ...            ARLINGTON     MA        02474   102      X      Trust
# 24       ...            ARLINGTON     MA        02474   101      X      Trust
# 25       ...            ARLINGTON     MA        02474   101      X      Trust
# 26       ...            ARLINGTON     MA        02474   102      X      Trust
# 27       ...            ARLINGTON     MA        02476   102      X      Trust
# 28       ...            ARLINGTON     MA        02474   102      X      Trust
# 29       ...            ARLINGTON     VA        60004   102      X      Trust
# ...      ...                   ...    ...          ...  ...    ...        ...
# 3169     ...             WINTHROP     MA        02152   104      X      Trust
# 3170     ...             WINTHROP     MA        02152   105      X      Trust
# 3171     ...             WINTHROP     MA        02152   105      X      Trust
# 3172     ...             WINTHROP     MA        02152   105      X      Trust
# 3173     ...             WINTHROP     MA        02152   105      X      Trust
# 3174     ...             WINTHROP     MA        02152   105      X      Trust
# 3175     ...             WINTHROP     MA        02152   111      X      Trust
# 3176     ...             WINTHROP     MA        02152   111      X      Trust
# 3177     ...             WINTHROP     MA        02152   111      X      Trust
# 3178     ...             WINTHROP     MA        02152   111      X      Trust
# 3179     ...             WINTHROP     MA        02152   111      X      Trust
# 3180     ...             WINTHROP     MA        02152   111      X      Trust
# 3181     ...             WINTHROP     MA        02152   111      X      Trust
# 3182     ...             WINTHROP     MA        02152   112      X      Trust
# 3183     ...             WINTHROP     MA        02152   112      X      Trust
# 3184     ...             WINTHROP     MA        02152   121      X      Trust
# 3185     ...               WOBURN     MA        01801   101      X      Trust
# 3186     ...               WOBURN     MA        01801   102      X      Trust
# 3187     ...               WOBURN     MA        01801   104      X      Trust
# 3188     ...               WOBURN     MA        01801   112      X      Trust
# 3189     ...               WOBURN     MA        01801   112      X      Trust
# 3190     ...               WOBURN     MA        01801   112      X      Trust
# 3191     ...               WOBURN     MA        01801   112      X      Trust
# 3192     ...               WOBURN     MA        01801   112      X      Trust
# 3193     ...               WOBURN     MA        01801   112      X      Trust
# 3194     ...               WOBURN     MA        01801   112      X      Trust
# 3195     ...               WOBURN     MA        01801   112      X      Trust
# 3196     ...               WOBURN     MA                112      X      Trust
# 3197     ...      WOLFEBORO FALLS     NH        03896   104      X      Trust
# 3198     ...            WORCESTER     MA        01602   105      X      Trust
#
#       O1_Trust O2_Trust O3_Trust  new_column
# 0        False    False    False         NaN
# 1        False    False    False         NaN
# 2        False    False    False         NaN
# 3        False    False    False         NaN
# 4        False    False    False         NaN
# 5        False    False    False         NaN
# 6        False    False    False         NaN
# 7        False    False    False         NaN
# 8        False    False    False         NaN
# 9        False    False    False         NaN
# 10       False    False    False         NaN
# 11       False    False    False         NaN
# 12       False    False    False         NaN
# 13       False    False    False         NaN
# 14       False    False    False         NaN
# 15       False    False    False         NaN
# 16       False    False    False         NaN
# 17       False    False    False         NaN
# 18       False    False    False         NaN
# 19       False    False    False         NaN
# 20       False    False    False         NaN
# 21        True     True    False         NaN
# 22       False    False    False         NaN
# 23       False     True     True         NaN
# 24       False    False    False         NaN
# 25       False    False    False         NaN
# 26       False    False    False         NaN
# 27       False    False    False         NaN
# 28       False    False    False         NaN
# 29       False    False    False         NaN
# ...        ...      ...      ...         ...
# 3169     False    False    False         NaN
# 3170     False    False    False         NaN
# 3171     False    False    False         NaN
# 3172     False    False    False         NaN
# 3173     False    False    False         NaN
# 3174     False    False    False         NaN
# 3175     False    False    False         NaN
# 3176     False    False    False         NaN
# 3177     False    False    False         NaN
# 3178     False    False    False         NaN
# 3179     False    False    False         NaN
# 3180     False    False    False         NaN
# 3181     False    False    False         NaN
# 3182     False    False    False         NaN
# 3183     False    False    False         NaN
# 3184     False    False    False         NaN
# 3185     False     True     True         NaN
# 3186     False    False    False         NaN
# 3187     False    False    False         NaN
# 3188     False    False    False         NaN
# 3189     False    False    False         NaN
# 3190     False    False    False         NaN
# 3191     False    False    False         NaN
# 3192     False    False    False         NaN
# 3193     False    False    False         NaN
# 3194     False    False    False         NaN
# 3195     False    False    False         NaN
# 3196     False    False    False         NaN
# 3197     False     True     True         NaN
# 3198     False    False    False         NaN
#
# [3199 rows x 23 columns]

# %%
df_rk1
# Out:
#      Owners           Parcel_ID Street_Number              Street Unit_Number  \
# NaN     NaN            1-12-24            33           PEARL AVE
# NaN     NaN          23-352-39           404       RESERVOIR AVE
# NaN     NaN           21-340-9            36            FENNO ST
# NaN     NaN         26-430E-20            85           GENEVA ST
# NaN     NaN         27-439Q-20            58           SQUIRE RD
# NaN     NaN          10-182-18            80          CALUMET ST
# NaN     NaN          22-383-31            12          FURNESS ST
# NaN     NaN      10-189-22A-9C           350   REVERE BEACH BLVD          9C
# NaN     NaN           7-212-3B           590   REVERE BEACH PKWY
# NaN     NaN            8-129-6            60         THORNTON ST
# NaN     NaN            8-132-6            17           WALNUT PL
# NaN     NaN        2-65-66-4-2             9       PIER VIEW AVE           2
# NaN     NaN            2-50-15            59         DOLPHIN AVE
# NaN     NaN           8-147-18            37          WALNUT AVE
# NaN     NaN         14-192H-25            33        BICKFORD AVE
# NaN     NaN         14-192K-19            29          DELANO AVE
# NaN     NaN         24-412C-20           152           FENLEY ST
# NaN     NaN        27-447-3-64           175             WARD ST          64
# NaN     NaN     10-189-43B-423           360   REVERE BEACH BLVD         423
# NaN     NaN           1-12-37A            58           SUMMER ST
# NaN     NaN            1-16-30           859        WINTHROP AVE
# NaN     NaN           8-148-26           539            BEACH ST
# NaN     NaN     10-189-43B-422           360   REVERE BEACH BLVD         422
# NaN     NaN           1-34A-3A           205      BELLINGHAM AVE
# NaN     NaN  8-160-161-1C-1514           376           OCEAN AVE        1514
# NaN     NaN         10-185D-11           466           REVERE ST
# NaN     NaN         28-438I-10           141            DERBY RD
# NaN     NaN       18-300-6A-10           100           ATWOOD ST          10
# NaN     NaN       33-459-3-504           109            SALEM ST         504
# NaN     NaN         7-110-8A-A            45        FLORENCE AVE           A
# ..      ...                 ...           ...                 ...         ...
# NaN     NaN           24-404-4            51            ADAMS ST
# NaN     NaN             1-30-4           141      BRADSTREET AVE
# NaN     NaN             1-36-4           135      BELLINGHAM AVE
# NaN     NaN             8-96-6            12              DIX ST
# NaN     NaN           10-184-4            41       BEACHLAND AVE
# NaN     NaN           24-404-3            57            ADAMS ST
# NaN     NaN             1-7-27          1107        WINTHROP AVE
# NaN     NaN             2-49-9           128        ATLANTIC AVE
# NaN     NaN            2-49-10             6            STATE RD
# NaN     NaN            2-49-11           124        ATLANTIC AVE
# NaN     NaN            3-40-24            32           CREST AVE
# NaN     NaN            7-110-1             5        FLORENCE AVE
# NaN     NaN           15-224-8            12       HARRINGTON ST
# NaN     NaN           8-146-11           583            BEACH ST
# NaN     NaN           8-151-13           592            BEACH ST
# NaN     NaN           8-136-16            54            DEHON ST
# NaN     NaN          26-400-27           142          LINCOLN ST
# NaN     NaN      10-189-22A-4F           350   REVERE BEACH BLVD          4F
# NaN     NaN         14-192K-23            45          DELANO AVE
# NaN     NaN         27-439V-1A           211          LANTERN RD
# NaN     NaN         27-439V-5B           237          LANTERN RD
# NaN     NaN          27-439V-7           249          LANTERN RD
# NaN     NaN          27-439V-8           259          LANTERN RD
# NaN     NaN          27-439W-3           216          LANTERN RD
# NaN     NaN          27-439W-4           230          LANTERN RD
# NaN     NaN          27-439W-5           242          LANTERN RD
# NaN     NaN          27-439W-6           256          LANTERN RD
# NaN     NaN      27-446445F-1B            83             WARD ST
# NaN     NaN        28-439J1-20           172          LANTERN RD
# NaN     NaN          22-362-18           150           WARREN ST
#
#                     Merged                          Owner_1  \
# NaN           33 PEARL AVE     WOODMAN FAMILY REALTY TRUST
# NaN      404 RESERVOIR AVE                  PAWLOWSKI PAUL
# NaN            36 FENNO ST                  PAWLOWSKI PAUL
# NaN           85 GENEVA ST                 MATTHEWS ROBERT
# NaN           58 SQUIRE RD                     BRADY PETER
# NaN          80 CALUMET ST                LAYAKOUBI BELAID
# NaN          12 FURNESS ST                 ALVINO ERNEST J
# NaN  350 REVERE BEACH BLVD                CARDUCCI SUSAN T
# NaN  590 REVERE BEACH PKWY         EXTRA SPACE PROP 76 LLC
# NaN         60 THORNTON ST           RODRIGUES MIGUEL JOSE
# NaN           17 WALNUT PL                  COB REALTY LLC
# NaN        9 PIER VIEW AVE                    KRAMER NANDA
# NaN         59 DOLPHIN AVE                   DESESA LAURIE
# NaN          37 WALNUT AVE                   DESESA LAURIE
# NaN        33 BICKFORD AVE                       GAO YIFAN
# NaN          29 DELANO AVE                    DODGE JACK P
# NaN          152 FENLEY ST                  DASCOLI ERNEST
# NaN            175 WARD ST                 WELLS JR ROBERT
# NaN  360 REVERE BEACH BLVD                 BOUMIL MARCIA M
# NaN           58 SUMMER ST                 GREATHEAD PETER
# NaN       859 WINTHROP AVE                     DELUCA ZELA
# NaN           539 BEACH ST                  BONILLA CARLOS
# NaN  360 REVERE BEACH BLVD     DEBORAH A REID LIVING TRUST
# NaN     205 BELLINGHAM AVE                   WELCH EMILY R
# NaN          376 OCEAN AVE   AZNIV IRREVOCABLE FAM GIFT TR
# NaN          466 REVERE ST                    SAINI GURNAM
# NaN           141 DERBY RD                      KHANDA LLC
# NaN          100 ATWOOD ST                      KHANDA LLC
# NaN           109 SALEM ST                   IOVANNA KARLA
# NaN        45 FLORENCE AVE                     SAINI MOHAN
# ..                     ...                              ...
# NaN            51 ADAMS ST  SALVATORE P FARO REAL ESTATE L
# NaN     141 BRADSTREET AVE                    FENLON PETER
# NaN     135 BELLINGHAM AVE                  KONCAR DALIBOR
# NaN              12 DIX ST                 RUBBICCO DONALD
# NaN       41 BEACHLAND AVE                 ESCOBAR CLAUDIA
# NaN            57 ADAMS ST                  FARO SALVATORE
# NaN      1107 WINTHROP AVE                   SAVARD JOSEPH
# NaN       128 ATLANTIC AVE                   BARRY MAUREEN
# NaN             6 STATE RD               POMEROY FRANCIS X
# NaN       124 ATLANTIC AVE               ROSSI JR EDWARD A
# NaN           32 CREST AVE               MARTELLI SEBATIAN
# NaN         5 FLORENCE AVE         FREED DAVID A AKA AARON
# NaN       12 HARRINGTON ST                      LANE JAMES
# NaN           583 BEACH ST                   SAVARD JOSEPH
# NaN           592 BEACH ST              BURROUGHS CONCETTA
# NaN            54 DEHON ST                 BECKERT ROGER P
# NaN         142 LINCOLN ST  142 LINCOLN STREET NOMINEE TRU
# NaN  350 REVERE BEACH BLVD      BOVA SALVATORE LIFE ESTATE
# NaN          45 DELANO AVE                     CAHILL SEAN
# NaN         211 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         237 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         249 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         259 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         216 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         230 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         242 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN         256 LANTERN RD        NORTHGATE APARTMENTS LLC
# NaN             83 WARD ST     RUMNEY FLATS APARTMENTS LLC
# NaN         172 LANTERN RD   ANGELINA GAMBARDELLA IRREVOCA
# NaN          150 WARREN ST                 SOLOMON KERRI A
#
#                              Owner_2                       Owner_3  \
# NaN        WOODMAN SHARYN A TRUSTEE     WOODMAN WILLIAM J TRUSTEE
# NaN                 MATTHEWS ROBERT
# NaN
# NaN                  PAWLOWSKI PAUL
# NaN                 ANNABELLE BRADY
# NaN                  CHERIFI SAADIA
# NaN                ALVINO BERNICE A
# NaN
# NaN
# NaN
# NaN          C/O CLIFTON MANAGEMENT
# NaN
# NaN
# NaN
# NaN
# NaN                  MARTIN PHILLIP
# NaN                 THERESA DASCOLI
# NaN                   WELLS MARYANN
# NaN
# NaN                   SHARI M TRAUB
# NaN               C/O JOANNE DUPUIS
# NaN                    ALBA BONILLA
# NaN          REID DEBORAH A TRUSTEE
# NaN                 WELCH BRIGHAM D
# NaN       MASEREJIAN JACK K TRUSTEE        NAROIAN SUZY M TRUSTEE
# NaN
# NaN
# NaN
# NaN
# NaN
# ..                               ...                           ...
# NaN
# NaN                   JANE S FENLON
# NaN    S HUSANOVIC & I K OSMANCEVIC
# NaN
# NaN
# NaN                   LORRAINE FARO
# NaN              GENEVIEVE B SAVARD
# NaN
# NaN
# NaN
# NaN
# NaN  LAFEYETE MGT GROUP REALTY TRUS
# NaN
# NaN              GENEVIEVE B SAVARD
# NaN                  LISA BURROUGHS
# NaN
# NaN         PABLA GURDEEP S TRUSTEE        DASS JASMINE S TRUSTEE
# NaN  GONZALEZ ANDREA J REMAINDERMAN   BOVA STEPHEN A REMAINDERMAN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN   GAMBARDELLA ANGELINA, TRUSTEE     ALBEE CHRISTINE L TRUSTEE
# NaN                  FLYNN THOMAS A
#
#            Mailing_Address     ...          Mailing_City State          Zip  \
# NaN           33 PEARL AVE     ...               REVERE    MA        02151
# NaN            5 MCCUE CIR     ...             ABINGTON    MA        02351
# NaN            5 MCCUE CIR     ...             ABINGTON    MA        02351
# NaN            5 MCCUE CIR     ...             ABINGTON    MA        02351
# NaN           P.O. BOX 201     ...               ACCORD    MA   02018-0201
# NaN         98 PROSPECT ST     ...                ACTON    MA        01720
# NaN            P O BOX 147     ...                ACTON    ME        04001
# NaN     3355 FERNSIDE BLVD     ...              ALAMEDA    CA        94501
# NaN         P O BOX 320099     ...           ALEXANDRIA    VA        22320
# NaN             P O BOX 76     ...             ALLISTON    MA        02134
# NaN         280 LINCOLN ST     ...              ALLSTON    MA        02134
# NaN           263 MAIN ST.     ...             AMESBURY    MA        01913
# NaN    64 BARTLETT`S REACH     ...             AMESBURY    MA        01913
# NaN    64 BARTLETT`S REACH     ...             AMESBURY    MA        01913
# NaN  141 NORTH PLEASANT ST     ...              AMHERST    MA   01004-0922
# NaN         80 COUNTY ROAD     ...              AMHERST    NH        03031
# NaN           16 COPLEY DR     ...              ANDOVER    MA        01810
# NaN            5 BUXTON CT     ...              ANDOVER    MA        01810
# NaN        11 KEYSTONE WAY     ...              ANDOVER    MA        01810
# NaN        7 LARCHMONT CIR     ...              ANDOVER    MA        01810
# NaN            43 VINE ST.     ...              ANDOVER    MA        01810
# NaN       5 MORNINGSIDE DR     ...              ANDOVER    MA        01810
# NaN      714 HOWARD`S LOOP     ...            ANNAPOLIS    MD        21401
# NaN        21360 SANDIA RD     ...         APPLE VALLEY    CA        92308
# NaN           15 PAWNEE DR     ...            ARLINGTON    MA        02474
# NaN         20 MELAINIE LN     ...            ARLINGTON    MA        02474
# NaN          20 MELANIE LN     ...            ARLINGTON    MA        02474
# NaN          20 MELANIE LN     ...            ARLINGTON    MA        02474
# NaN        504 APPLETON ST     ...            ARLINGTON    MA        02476
# NaN          20 MELANIE LN     ...            ARLINGTON    MA        02474
# ..                     ...     ...                   ...   ...          ...
# NaN           244 COURT RD     ...             WINTHROP    MA        02152
# NaN          19 SARGENT ST     ...             WINTHROP    MA        02152
# NaN        114 PLEASANT ST     ...             WINTHROP    MA        02152
# NaN          14 PERKINS ST     ...             WINTHROP    MA        02152
# NaN   98 WINTHROP SHORE DR     ...             WINTHROP    MA        02152
# NaN           244 COURT RD     ...             WINTHROP    MA        02152
# NaN      56 WASHINGTON AVE     ...             WINTHROP    MA        02152
# NaN         11 CRESCENT ST     ...             WINTHROP    MA        02152
# NaN          77 BOWDOIN ST     ...             WINTHROP    MA        02152
# NaN          71 SHIRLEY ST     ...             WINTHROP    MA        02152
# NaN            77 COURT ST     ...             WINTHROP    MA        02152
# NaN          22 SUMMIT AVE     ...             WINTHROP    MA        02152
# NaN            8 ARGYLE ST     ...             WINTHROP    MA        02152
# NaN      56 WASHINGTON AVE     ...             WINTHROP    MA        02152
# NaN           35 NAHANT ST     ...             WINTHROP    MA        02152
# NaN         600 SHIRLEY ST     ...             WINTHROP    MA        02152
# NaN          3 O`CONNOR LN     ...               WOBURN    MA        01801
# NaN         38 ROBINSON RD     ...               WOBURN    MA        01801
# NaN           122 GREEN ST     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA        01801
# NaN   150 PRESIDENTIAL WAY     ...               WOBURN    MA
# NaN    POST OFFICE BOX 323     ...      WOLFEBORO FALLS    NH        03896
# NaN          406 LOVELL ST     ...            WORCESTER    MA        01602
#
#      LUC Not_OO  Substring1 O1_Trust O2_Trust  O3_Trust  new_column
# NaN  101    NaN       Trust     True     True      True         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN   31      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  102      X       Trust     True     True     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False     True      True         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  102      X       Trust    False    False     False         NaN
# ..   ...    ...         ...      ...      ...       ...         ...
# NaN  104      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  105      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  111      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  121      X       Trust    False    False     False         NaN
# NaN  101      X       Trust    False     True      True         NaN
# NaN  102      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  112      X       Trust    False    False     False         NaN
# NaN  104      X       Trust    False     True      True         NaN
# NaN  105      X       Trust    False    False     False         NaN
#
# [12038 rows x 22 columns]

# %% [markdown]
# ### data cleaning functions

# %%
#data cleaning
def upperletter(row):
    return row.str.upper()
def trimdata(row):
    return row.str.strip()
df_rk1[['Merged','Mailing_Address','Owner_1','Owner_2','Owner_3']] = df_rk1[['Merged','Mailing_Address','Owner_1','Owner_2','Owner_3']].apply(trimdata, axis=1).apply(upperletter, axis=1)
df_rk2[['Merged','Street_name','Name']] = df_rk2[['Merged','Street_name','Name']].apply(trimdata, axis=1).apply(upperletter, axis=1)
df_mailing = df_mailing.apply(trimdata, axis=1)

# %%
#mailing.bedroom.unit dataset
df_mbu = pd.read_excel('mailing.bedroom.unit.xlsx')
df_mbu.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_mbu = df_mbu.drop(columns=['Unnamed:_2','Unnamed:_9','Unnamed:_13'])
df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']] = df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']].apply(trimdata, axis=1)
df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']] = df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']].apply(upperletter, axis=1)

# %%
df_mbu
# Out:
#                   Parcel_ID     House_#                             Location  \
# 0      1-1-6-1                           SUNNYSIDE AVE
# 1      1-1-6-2                           SUNNYSIDE AVE
# 2      1-1-6-3                           CRYSTAL AVE
# 3      1-1-6-4                           SUNNYSIDE AVE
# 4      1-1-6-5               92          CRYSTAL AVE
# 5      1-1-6-6               98          CRYSTAL AVE
# 6      1-1-6-7               100         CRYSTAL AVE
# 7      1-1-6-10              102         SUMMER ST
# 8      1-1-6-11              104         SUMMER ST
# 9      1-1-6-12              103         SUMMER ST
# 10     1-1-6-13              101         SUMMER ST
# 11     1-1-6-14              99          SUMMER ST
# 12     1-1-6-15              95          SUMMER ST
# 13     1-1-6-18                          CRYSTAL AVE
# 14     1-1-6-19                          CRYSTAL AVE
# 15     1-10-3                149         CRESCENT AVE
# 16     1-10-5                157         CRESCENT AVE
# 17     1-10-7                167         CRESCENT AVE
# 18     1-10-8                169         CRESCENT AVE
# 19     1-10-9                175         CRESCENT AVE
# 20     1-10-10               181         CRESCENT AVE
# 21     1-10-11               189         CRESCENT AVE
# 22     1-10-12               193         CRESCENT AVE
# 23     1-10-13               33          WEBSTER ST
# 24     1-10-14               37          WEBSTER ST
# 25     1-10-15               165         PEARL AVE
# 26     1-10-16               169         PEARL AVE
# 27     1-10-17               171         PEARL AVE
# 28     1-10-18               175         PEARL AVE
# 29     1-10-19               181         PEARL AVE
# ...                     ...         ...                                  ...
# 15079  29-433A-1B-406        770         WASHINGTON AVE
# 15080  29-433A-1B-501        770         WASHINGTON AVE
# 15081  29-433A-1B-502        770         WASHINGTON AVE
# 15082  29-433A-1B-503        770         WASHINGTON AVE
# 15083  29-433A-1B-504        770         WASHINGTON AVE
# 15084  10-176-4B                         SAGAMORE ST
# 15085  10-176-4C                         SAGAMORE ST
# 15086  4-92-14A                          GARFIELD AVE
# 15087  8-138-7C              9           DEHON ST
# 15088  2-139-5A              90          OCEAN AVE
# 15089  11-188H-24A           14          BEVERLY ST
# 15090  11-188H-25A           6           BEVERLY ST
# 15091  26-423F-19A                       SAVAGE ST
# 15092  3-39-21A-1            16          BRADSTREET AVE
# 15093  3-39-21A-2            16          BRADSTREET AVE
# 15094  2-50-12A-1            33          WAVE AVE
# 15095  2-50-12A-2            33          WAVE AVE
# 15096  2-50-12A-3            33          WAVE AVE
# 15097  23-344-1A-A           10          SPRING AVE
# 15098  23-344-1A-B           10          SPRING AVE
# 15099  8-138-10A             17          DEHON ST
# 15100  9-166&168-10A                     OCEAN AVE
# 15101  9-166&168-9A                      OCEAN AVE
# 15102  9-166&168-8A                      OCEAN AVE
# 15103  9-158-1A                          BAKER AVE
# 15104  30-435C-9A            320         CHARGER ST
# 15105  30-435C-8A            320         SQUIRE REAR RD
# 15106  30-435C-7C                        SQUIRE REAR RD
# 15107  16-239-5A-1           127         HARRIS ST
# 15108  16-239-5A-2           127         HARRIS ST
#
#            Unit_#                          Owner  \
# 0                                 CITY OF REVERE
# 1                  COMMONWEALTH OF MASSACHUSETTS
# 2                                 CITY OF REVERE
# 3                                 CITY OF REVERE
# 4                             ANDERSON  ROBERT B
# 5                                  DORSI VALERIE
# 6                                    LEMUS MARIO
# 7                                  KATRANIS JOHN
# 8                                   CHILES KEVIN
# 9                                     KNOLL MARK
# 10                               BELL MICHELLE R
# 11                                 MEDINA SERGIO
# 12                               RINALDI ANNETTE
# 13                                     HE ZHIHUA
# 14                                     HE ZHIHUA
# 15                               TROIANO THERESA
# 16                                 BUCKLEY SUSAN
# 17                              PITRONE JR PETER
# 18                               KERSHAW LARRY N
# 19                               HERRERA DAMARIS
# 20                              GRZECZKA BARTOSZ
# 21                                MOSCONE ALBERT
# 22                         CRESCENT AVENUE TRUST
# 23                                  MENDOZA JOSE
# 24                   WEBSTER AVENUE REALTY TRUST
# 25                               VASQUEZ ELSIDES
# 26                                 NAGAGE RUVANI
# 27                                  CORN WILLIAM
# 28                           ZIELINSKI TIMOTHY E
# 29                           ECHEVARRIA BETTSALY
# ...           ...                            ...
# 15079  406                               SHI YIN
# 15080  501                      STEPHEN RUGGIERO
# 15081  502                    VINCENT CENTOFANTI
# 15082  503                     JOANNE CENTOFANTI
# 15083  504               ELIZABETH HERRERA NEIRA
# 15084                        JENNY SAYI OLIVARES
# 15085                          WILLIAM SETTIPANE
# 15086                             CITY OF REVERE
# 15087                             DCM REALTY LLC
# 15088                        90 OCEAN AVENUE LLC
# 15089                        HUMPHREY STREET LLC
# 15090                        HUMPHREY STREET LLC
# 15091                                    BUI LEE
# 15092  1                          HANNAH M ALLEN
# 15093  2                     MARCIA L DE MENEZES
# 15094  1                              AMAL NADIR
# 15095  2                             DRISS NADIR
# 15096  3                            RACHID NADIR
# 15097  A                               ADRI PAUL
# 15098  B                        JAMES D HENDRICK
# 15099                                  DEHON LLC
# 15100                      500 OCEAN AVENUE, LLC
# 15101                      500 OCEAN AVENUE, LLC
# 15102               LIXI HOSPITALITY REVERE, INC
# 15103                   MASS BAY TRANS AUTHORITY
# 15104                         R & S REALTY TRUST
# 15105                         R & S REALTY TRUST
# 15106                         R & S REALTY TRUST
# 15107  1                MARINA ANN GABRIEL TRUST
# 15108  2                         LONDONO BEATRIZ
#
#                          Second_Owner                Third_Owner  \
# 0
# 1
# 2                  C/O MAYOR`S OFFICE
# 3
# 4                ANDERSON CHRISTINE P
# 5                     JOSEPH DORSI JR
# 6
# 7
# 8
# 9                       KNOLL MARLENE
# 10                         BELL JAMES
# 11                     VERGARA ISALIA
# 12
# 13                           YANG FEI
# 14                           YANG FEI
# 15                    TROIANO THERESA
# 16
# 17                   PITRONE JR PETER
# 18                  KERSHAW DOLORES I
# 19            ECHEVERRI ELKIN EDUARDO
# 20
# 21                  VALERIE A MOSCONE
# 22        MERCURIO JAMES  AND MICHAEL     MERCURIO-ASH CLAUDETTE
# 23
# 24     EMILIE ORLANDO BUCKLEY, TRUSTE
# 25
# 26
# 27                       LYNDA M CORN
# 28
# 29              ECHEVARRIA NICOLLETTE
# ...                               ...                        ...
# 15079
# 15080
# 15081
# 15082
# 15083
# 15084       MORENA HOSSABETH OLIVARES
# 15085                 PAULA SETTIPANE
# 15086
# 15087
# 15088
# 15089
# 15090
# 15091                        BUI HONG
# 15092              ALEXANDRA L STAIRS
# 15093
# 15094
# 15095
# 15096
# 15097
# 15098                      RUBY MERAN
# 15099
# 15100  C/O GATE RESIDENTIAL PROPERTIE
# 15101  C/O GATE RESIDENTIAL PROPERTIE
# 15102                  C/O LIXI GROUP
# 15103
# 15104                 CARUSO JR RALPH
# 15105                CARUSO JR  RALPH
# 15106                 CARUSO JR RALPH
# 15107      MARINA ANN GABRIEL TRUSTEE  MARYANN R GABRIEL TRUSTEE
# 15108
#
#       Mailing_Street_Address               Mailing_City Mailing_State_  \
# 0               281 BROADWAY  REVERE                        MA
# 1             20 SOMERSET ST  BOSTON                        MA
# 2               281 BROADWAY  REVERE                        MA
# 3               281 BROADWAY  REVERE                        MA
# 4             92 CRYSTAL AVE  REVERE                        MA
# 5             98 CRYSTAL AVE  REVERE                        MA
# 6            75 WILLIAM G DR  TEWSBURY                      MA
# 7              102 SUMMER ST  Revere                        MA
# 8            83 PEMBERTON ST  REVERE                        MA
# 9              55 BURNHAM RD  FREEDOM                       NH
# 10             101 SUMMER ST  Revere                        MA
# 11              99 SUMMER ST  Revere                        MA
# 12              95 SUMMER ST  REVERE                        MA
# 13           126 CRYSTAL AVE  Revere                        MA
# 14           126 CRYSTAL AVE  Revere                        MA
# 15          149 CRESCENT AVE  REVERE                        MA
# 16          157 CRESCENT AVE  REVERE                        MA
# 17          167 CRESCENT AVE  REVERE                        MA
# 18          169 CRESCENT AVE  REVERE                        MA
# 19          175 CRESCENT AVE  Revere                        MA
# 20            292 NEWBURY ST  BOSTON                        MA
# 21          189 CRESCENT AVE  REVERE                        MA
# 22          128 CRESCENT AVE  REVERE                        MA
# 23             33 WEBSTER ST  REVERE                        MA
# 24             37 WEBSTER ST  REVERE                        MA
# 25             165 PEARL AVE  REVERE                        MA
# 26             169 PEARL AVE  Revere                        MA
# 27             171 PEARL AVE  REVERE                        MA
# 28             175 PEARL AVE  REVERE                        MA
# 29             181 PEARL AVE  REVERE                        MA
# ...                      ...                        ...            ...
# 15079     770 WASHINGTON AVE  Revere                        MA
# 15080     770 WASHINGTON AVE  Revere                        MA
# 15081     770 WASHINGTON AVE  Revere                        MA
# 15082     770 WASHINGTON AVE  Revere                        MA
# 15083     770 WASHINGTON AVE  Revere                        MA
# 15084          4 SAGAMORE ST  REVERE                        MA
# 15085          2 SAGAMORE ST  REVERE                        MA
# 15086           281 BROADWAY  REVERE                        MA
# 15087         25 RENEE DRIVE  WAKEFIELD                     MA
# 15088         140 TREMONT ST  EVERETT                       MA
# 15089        93 ATLANTIC AVE  SWAMPSCOTT                    MA
# 15090        93 ATLANTIC AVE  SWAMPSCOTT                    MA
# 15091           56 GOLDIE ST  REVERE                        MA
# 15092      16 BRADSTREET AVE  REVERE                        MA
# 15093      16 BRADSTREET AVE  REVERE                        MA
# 15094            33 WAVE AVE  Revere                        MA
# 15095            33 WAVE AVE  Revere                        MA
# 15096            33 WAVE AVE  Revere                        MA
# 15097          10 SPRING AVE  Revere                        MA
# 15098          10 SPRING AVE  Revere                        MA
# 15099           P.O. BOX 365  REVERE                        MA
# 15100    265 FRANKLIN STREET  BOSTON                        MA
# 15101        265 FRANKLIN ST  BOSTON                        MA
# 15102      260 WEST ROUTE 59  NANUET                        NY
# 15103          10 PARK PLAZA  BOSTON                        MA
# 15104         320 CHARGER ST  REVERE                        MA
# 15105         320 CHARGER ST  REVERE                        MA
# 15106         320 CHARGER ST  REVERE                        MA
# 15107          195 SQUIRE RD  REVERE                        MA
# 15108          127 HARRIS ST  REVERE                        MA
#
#             Mailing_Zip  LUC  #_of_Units  #_of_Bedrooms
# 0      02151             930           0              0
# 1      02108             920           0              0
# 2      02151             930           0              0
# 3      02151             930           0              0
# 4      02151             101           1              3
# 5      02151             101           1              3
# 6      01876             101           1              3
# 7      02151             101           1              2
# 8      02151             101           1              4
# 9      03836             101           1              5
# 10     02151             101           1              3
# 11     02151             101           1              3
# 12     02151             101           1              3
# 13     02151             106           0              0
# 14     02151             131           0              0
# 15     02151             104           2              4
# 16     02151             104           2              4
# 17     02151             105           3              5
# 18     02151             105           3              9
# 19     02151             101           1              3
# 20     02115             104           2              5
# 21     02151             101           1              4
# 22     02151             104           2              4
# 23     02151             101           1              2
# 24     02151             101           1              4
# 25     02151             104           2              4
# 26     02151             104           2              4
# 27     02151             101           1              3
# 28     02151             101           1              3
# 29     02151             104           2              4
# ...                 ...  ...         ...            ...
# 15079  02151             102           1              1
# 15080  02151             102           1              2
# 15081  02151             102           1              2
# 15082  02151             102           1              2
# 15083  02151             102           1              1
# 15084  02151             132           0              0
# 15085  02151             132           0              0
# 15086  02151             930           0              0
# 15087  01880             130           0              0
# 15088  02149             130           0              0
# 15089  01907-2407        130           0              0
# 15090  01907-2407        130           0              0
# 15091  02151             130           0              0
# 15092  02151             102           1              2
# 15093  02151             102           1              3
# 15094  02151             102           1              3
# 15095  02151             102           1              3
# 15096  02151             102           1              3
# 15097  02151             102           1              3
# 15098  02151             102           1              3
# 15099  02151              13           9              8
# 15100  02109             920           0              0
# 15101  02109             920           0              0
# 15102  10954             920           0              0
# 15103  02116             920           0              0
# 15104  02151             316           3              0
# 15105  02151             316           1              0
# 15106  02151             316           2              0
# 15107  02151             102           1              3
# 15108  02151             102           1              3
#
# [15109 rows x 14 columns]

# %% [markdown]
# ### calculate address mismatch by mailing address

# %%
# print(df_rk1.shape)
# print(df_mismatch.shape)
# print(df_mismatch.columns)
# print(df_rk1.columns)
print("mailing mismatch percent:",df_mismatch.shape[0]/total0)
merged = set(df_rk2.Name)
df_extract = []
rv = 0
for row in df_rk1.itertuples():
    if row.Owner_1 in merged or row.Owner_2 in merged or row.Owner_3 in merged:
        df_extract.append(row)
    if row.Mailing_City == 'REVERE':
        rv += 1
df_extract = pd.DataFrame(df_extract) 
rv
# Out:
# mailing mismatch percent: 0.26574181757767074
# 0

# %%
#extract dataframe that address exist in both sheets.
merged2 = set(df_rk2.Merged)
tmp = []
for row in df_rk1.itertuples():
    if row.Merged in merged2 or row.Mailing_Address in merged2:
        tmp.append(row)
df_extract2 = pd.DataFrame(tmp)

# %%
#create a dict to store all the owners that have multiple properties based on df_rk2.
#create a list to store the owner names.
#or it may result in duplicate names.
addr_dict={}
multi_owner = []
multi = 0
for row in df_rk2.itertuples():
    Merged2 = str(row.House_number)+' '+row.Street_name
    if row.Name not in addr_dict:
        addr_dict[row.Name] = [Merged2]
    else:
        if [Merged2] == addr_dict[row.Name]:
            continue
        else:
            addr_dict[row.Name].append(Merged2)
            multi_owner.append(row.Name)

# %%
len(addr_dict)
# Out:
# 36609

# %%
#measure the percentage by person
comp_names = []
num = 0
all_addr = []
noop_addr = []
for row in df_rk1.itertuples():
    if row.Owner_1 in addr_dict or row.Owner_2 in addr_dict or row.Owner_3 in addr_dict:
        all_addr.append(row.Merged)
    if row.Owner_1 in addr_dict:
        num+=1
        if row.Merged not in addr_dict[row.Owner_1]:
            comp_names.append(row.Owner_1)
            noop_addr.append(row.Merged)
    if row.Owner_2 in addr_dict:
        num+=1
        if row.Merged not in addr_dict[row.Owner_2]:
            comp_names.append(row.Owner_2)
            noop_addr.append(row.Merged)
    if row.Owner_3 in addr_dict:
        num+=1
        if row.Merged not in addr_dict[row.Owner_3]:
            comp_names.append(row.Owner_3)
            noop_addr.append(row.Merged)
m_owners = set(comp_names)
all_addr = set(all_addr)
noop_addr = set(noop_addr)
print('names with different address:',len(m_owners))
print('names appear in both sheets:',num)
print('percent that a person have multiple properties:',len(m_owners)/num)
print(len(all_addr))
print(len(noop_addr))
print(len(noop_addr)/len(all_addr))
# Out:
# names with different address: 807
# names appear in both sheets: 4136
# percent that a person have multiple properties: 0.19511605415860736
# 3088
# 730
# 0.23639896373056996

# %%
addr_dict
# Out:
# {'HORROCKS RUTH E': ['1 A ST'],
#  'MACANCELA SONIA': ['11 ABRUZZI ST'],
#  'MACANCELA JHONNY OSWALDO': ['11 ABRUZZI ST'],
#  'SANTACRUZ KATHERINE JANETH': ['11 ABRUZZI ST'],
#  'MACANCELA KELLY N': ['11 ABRUZZI ST'],
#  'MACANCELA CRISTOPHER A': ['11 ABRUZZI ST'],
#  'HERNANDEZ ROBERTO A': ['11 ABRUZZI ST'],
#  'OCASIO SALVADORA': ['11 ABRUZZI ST'],
#  'BARRETO EDMARIET': ['11 ABRUZZI ST'],
#  'HERNANDEZ SONYA E': ['11 ABRUZZI ST'],
#  'SAENZ JAMIE': ['13 ABRUZZI ST'],
#  'SAENZ JUANCARLOS': ['15 ABRUZZI ST'],
#  'SAENZ MARTHA L': ['15 ABRUZZI ST'],
#  'BELMONTE DEBORAH': ['19 ABRUZZI ST'],
#  'BELMONTE ANTHONY A': ['19 ABRUZZI ST'],
#  'ELDEEB AMIR K': ['29 ABRUZZI ST'],
#  'ABDOU NISRINE': ['29 ABRUZZI ST'],
#  'ABDOU ILYASS': ['29 ABRUZZI ST'],
#  'SOLEMINA REGIS R': ['30 ABRUZZI ST'],
#  'PEREIRA MARCIO I': ['37 ABRUZZI ST'],
#  'PEREIRA JUSSANE': ['37 ABRUZZI ST'],
#  'OLIVEIRA CILEIMAR S': ['37 ABRUZZI ST'],
#  'COUTINHO ISABEL O': ['37 ABRUZZI ST'],
#  'SILVA GILSON': ['37 ABRUZZI ST'],
#  'COUTINHO ALINE OLIVEIRA': ['37 ABRUZZI ST'],
#  'SILVA JENNA S': ['37 ABRUZZI ST'],
#  'VENTURA JAEDER': ['37 ABRUZZI ST'],
#  'EBEJA ARMAND': ['42 ABRUZZI ST'],
#  'POWERS DOLORES': ['43 ABRUZZI ST'],
#  'AGUILAR MARLENY': ['52 ABRUZZI ST'],
#  'VELASQUEZ ARIEL O': ['52 ABRUZZI ST'],
#  'PERRETTI DOMENIC A': ['65 ABRUZZI ST'],
#  'PERRETTI LORETTA': ['65 ABRUZZI ST'],
#  'PERRETTI COREY J': ['65 ABRUZZI ST'],
#  'ORREGO NEBARDO': ['68 ABRUZZI ST'],
#  'SHELDON RICHARD W': ['68 ABRUZZI ST'],
#  'ORREGO MALLORY': ['68 ABRUZZI ST'],
#  'BERNARD LLEANNA G': ['68 ABRUZZI ST'],
#  'WAPLE JENNIFER M': ['69 ABRUZZI ST'],
#  'RIVERA HECTOR A': ['69 ABRUZZI ST'],
#  'RIVERA SUSAN': ['69 ABRUZZI ST'],
#  'CARSON ZACKARY RYAN': ['69 ABRUZZI ST'],
#  'RIVERA ALEXANDER': ['69 ABRUZZI ST'],
#  'ORTEZ ENNA R': ['73 ABRUZZI ST'],
#  'GUTIERREZ DANIEL A': ['73 ABRUZZI ST', '42 AGAWAM ST'],
#  'GUTIERREZ CECY': ['73 ABRUZZI ST'],
#  'BRANGIFORTE NICOLAS M': ['73 ABRUZZI ST'],
#  'GUTIERREZ LIZBETH': ['73 ABRUZZI ST'],
#  'LE MINI HA': ['75 ABRUZZI ST'],
#  'LE DEXTER': ['75 ABRUZZI ST'],
#  'DION MICHELLE': ['75 ABRUZZI ST'],
#  'DION CHRISTOPHER S': ['75 ABRUZZI ST'],
#  'LUCIFORA TORI': ['75 ABRUZZI ST'],
#  'CIOFFI PATRICIA J': ['1 ADAMS CT'],
#  'FOTI SALVATORE P': ['1 ADAMS CT'],
#  'CUSTOVIC ENVER': ['2 ADAMS CT'],
#  'LYONS MARILYN C': ['2 ADAMS CT'],
#  'WINER BRIAN': ['2 ADAMS CT'],
#  'MEDEIROS DEBORAH ANN': ['3 ADAMS CT'],
#  'FUSCO CLIFFORD': ['3 ADAMS CT'],
#  'PUBLICOVER MAXINE A': ['3 ADAMS CT'],
#  'QUEVEDO YOLANDA': ['4 ADAMS CT'],
#  'DIRUZZA JOSEPH A': ['4 ADAMS CT'],
#  'DIRUZZA JUDITH MARY': ['4 ADAMS CT'],
#  'BAKHSISS TRACEY A': ['4 ADAMS CT'],
#  'FLICKINGER ROSE': ['5 ADAMS CT'],
#  'CONNORS TERRY-ANN': ['5 ADAMS CT'],
#  'MUDGE RUTH B': ['5 ADAMS CT'],
#  'BEL GRINI MOHAMED': ['5 ADAMS CT'],
#  'CHAOUI MERYEM': ['5 ADAMS CT'],
#  'COUNTIE EDMUND A': ['6 ADAMS CT'],
#  'MARGARECI ANTHONY FRANK': ['6 ADAMS CT'],
#  'FANTASIA ANGELA': ['6 ADAMS CT'],
#  'THEALL GAIL P': ['6 ADAMS CT'],
#  'FELIX AMYBETH': ['6 ADAMS CT'],
#  'EL ARAYACHE RAHMA': ['7 ADAMS CT'],
#  'LIMOLI ROBIN A': ['7 ADAMS CT'],
#  'MARSTON BEATRICE': ['7 ADAMS CT'],
#  'BERBERENA JORGE L': ['7 ADAMS CT'],
#  'SANTANIELLO ELAINE D': ['7 ADAMS CT'],
#  'PEACH JEAN': ['8 ADAMS CT'],
#  'CHAU SANDY': ['8 ADAMS CT'],
#  'BATISTA LILLIAN': ['8 ADAMS CT'],
#  'MAK VONN': ['8 ADAMS CT'],
#  'DZEKO SUAD': ['9 ADAMS CT'],
#  'HAMDI NAIMA': ['9 ADAMS CT'],
#  'MOHAMMED KHOUYA': ['9 ADAMS CT'],
#  'GARCIA ORLANDO': ['9 ADAMS CT'],
#  'DEGARCIA ARGENTINA': ['9 ADAMS CT'],
#  'PROCHILO JOSEPH J': ['10 ADAMS CT'],
#  'ABDULLA KAMAL QADIR': ['10 ADAMS CT'],
#  'ABDULLA AMINA ALI': ['10 ADAMS CT'],
#  'FALZONE LAURETTA': ['10 ADAMS CT'],
#  'KEHAYOGLOU JOHN T': ['10 ADAMS CT'],
#  'RIOS MARIA LOUDES': ['11 ADAMS CT'],
#  'STAFFORD JUSTIN': ['11 ADAMS CT'],
#  'HARLOW NANCY': ['11 ADAMS CT'],
#  'AZZAOUI NADRA': ['11 ADAMS CT'],
#  'HAKIMI ABDUL F': ['11 ADAMS CT'],
#  'LAVINE ROBERT': ['12 ADAMS CT'],
#  'PETRELLO CHERYL A': ['12 ADAMS CT'],
#  'TIPPETT JENNIE ELAINE': ['12 ADAMS CT'],
#  'BASTOS LEDA': ['12 ADAMS CT'],
#  'LOPES LIDIA MARIA': ['13 ADAMS CT'],
#  'MCCONNELL SARINA MARIE': ['13 ADAMS CT'],
#  'BARNABY GLORIA': ['13 ADAMS CT'],
#  'YEM SALIN': ['13 ADAMS CT'],
#  'LUDOVICI RONALD A': ['14 ADAMS CT'],
#  'GATTA JOSEPHINE': ['14 ADAMS CT'],
#  'BAHRAOUI ELFATIMI': ['15 ADAMS CT'],
#  'SAHAFI FRIHA': ['15 ADAMS CT'],
#  'BIRD SHARON MARIE': ['15 ADAMS CT'],
#  'DIBIASE MICHAEL P': ['11 ADAMS ST'],
#  'CIRIELLO GAETANO': ['11 ADAMS ST'],
#  'CIRIELLO DORA': ['11 ADAMS ST'],
#  'CAFARELLI IDA': ['21 ADAMS ST'],
#  'BRADSHAW RUPERT M': ['43 ADAMS ST'],
#  'RICHARDSON WALTER': ['43 ADAMS ST'],
#  'BRADSHAW GEORGINA': ['43 ADAMS ST'],
#  'KING PATRICK ANTHONY': ['43 ADAMS ST'],
#  'BELLE-KING CAROL J': ['43 ADAMS ST'],
#  'BRADSHAW JAMARIE': ['43 ADAMS ST'],
#  'CHALLENGER SHAMAR K': ['43 ADAMS ST'],
#  'FOUNTAIN GINA E': ['47 ADAMS ST'],
#  'FOUNTAIN NEAL H': ['47 ADAMS ST'],
#  'GRIMALDI ADA M': ['51 ADAMS ST'],
#  'RIVERA PABLO': ['51 ADAMS ST'],
#  'GRIMALDI ADA C': ['51 ADAMS ST'],
#  'MOSCATO ANDREW J': ['54 ADAMS ST'],
#  'HESTER SEAN': ['57 ADAMS ST'],
#  'RUDECINDO RAMON': ['59 ADAMS ST'],
#  'RUDECINDO AURORA': ['59 ADAMS ST'],
#  'RUDECINDO RAMON A': ['59 ADAMS ST'],
#  'RUDECINDO PAOLA': ['59 ADAMS ST'],
#  'RUDECINDO BRENDALISSE': ['59 ADAMS ST'],
#  'RUDECINDO OSCAR': ['59 ADAMS ST'],
#  'SENIBALDI NICOLE A': ['62 ADAMS ST'],
#  'SENIBALDI MICHAEL E': ['62 ADAMS ST'],
#  'SENIBALDI MARK S': ['62 ADAMS ST'],
#  'MACALLISTER ANTHONY PAUL': ['62 ADAMS ST'],
#  'MORALES DOLORES C': ['65 ADAMS ST'],
#  'BLANCO FRANCISCO A': ['65 ADAMS ST'],
#  'ZAVALA SAMUEL A': ['65 ADAMS ST'],
#  'MORALES KATHERINE E': ['65 ADAMS ST'],
#  'TEJADA IVAN W': ['66 ADAMS ST'],
#  'SERRANO IRIS C': ['66 ADAMS ST'],
#  'COPPOLA MARIE R': ['86 ADAMS ST'],
#  'WILLIAMSON CHERYL A': ['86 ADAMS ST'],
#  'WOODLAND GLORIA T': ['88 ADAMS ST'],
#  'WOODLAND MICHAEL J': ['88 ADAMS ST'],
#  'CRONIN JOANNE A': ['90 ADAMS ST'],
#  'TEMPESTA BARBARA R': ['92 ADAMS ST'],
#  'HECKLEY RICHARD O': ['95 ADAMS ST'],
#  'HECKLEY LORIE J': ['95 ADAMS ST'],
#  'HECKLEY SAMANTHA MARIE': ['95 ADAMS ST'],
#  'VELAZQUEZ JOLERIE': ['104 ADAMS ST'],
#  'BRUNO JULIA L': ['106 ADAMS ST'],
#  'MARTIN SHAUNA JANINE': ['107 ADAMS ST'],
#  'MCGAH DEBORAH': ['108 ADAMS ST'],
#  'BOUHAJBANE SAID': ['109 ADAMS ST'],
#  'HADIF HAYAT': ['109 ADAMS ST'],
#  'TRONCOSO ISABEL': ['110 ADAMS ST'],
#  'PENA T ISAMAR': ['110 ADAMS ST'],
#  'DISISTO LYDIA J': ['114 ADAMS ST'],
#  'SPAGNUOLO JESSICA L': ['116 ADAMS ST'],
#  'DELIC BOJANA': ['117 ADAMS ST'],
#  'MORICO PATRICIA': ['118 ADAMS ST'],
#  'WEEKS JAMES LOUIS': ['119 ADAMS ST'],
#  'BENINATI MARY R': ['119 ADAMS ST'],
#  'FERRAGAMO JOAN R': ['120 ADAMS ST'],
#  'DEVITO DEVON E': ['133 ADAMS ST'],
#  'DEVITO SAMANTHA J': ['133 ADAMS ST'],
#  'GIPSON CATHERINE M': ['134 ADAMS ST'],
#  'SPAGNUOLO DIANA L': ['135 ADAMS ST'],
#  'SPAGNUOLO LAWRENCE': ['135 ADAMS ST'],
#  'SPAGNUOLO CHRISTINA': ['135 ADAMS ST'],
#  'SPAGNUOLO DANIEL J': ['135 ADAMS ST'],
#  'SPAGNUOLO MATTHEW': ['135 ADAMS ST'],
#  'VALENTIN JOHN M': ['136 ADAMS ST'],
#  'VALENTIN BRITTANY M': ['136 ADAMS ST'],
#  'LYONS PAULINE M': ['138 ADAMS ST'],
#  'ATTARDO DENISE M': ['140 ADAMS ST'],
#  'GROCH KEVIN': ['140 ADAMS ST'],
#  'TROCHEZ ELAINE E': ['9 AGATHA ST'],
#  'VEERASAMMY VEERANGA S': ['9 AGATHA ST'],
#  'AYAR SALAHEDDINE': ['9 AGATHA ST'],
#  'VEERASAMMY CHRISTINA I': ['9 AGATHA ST'],
#  'STANTON JACOB': ['9 AGATHA ST'],
#  'BREA ARAMIS E': ['11 AGATHA ST'],
#  'GORDON AMBER LEE': ['11 AGATHA ST'],
#  'LOMBARD JAMES JOSEPH': ['13 AGATHA ST'],
#  'MARCHANTE CHRISTIAN': ['13 AGATHA ST'],
#  'ZELAYANDIA STEPHANIE B': ['13 AGATHA ST'],
#  'ZELAYANDIA RENE ALBERTO': ['13 AGATHA ST'],
#  'POJOY ALIDA L': ['15 AGATHA ST'],
#  'ORELLANA KIMBERLY A': ['17 AGATHA ST'],
#  'OCHOA DIEGO A': ['17 AGATHA ST', '131 ATLANTIC AVE'],
#  'ROSCOE JANELLE MARIE': ['17 AGATHA ST'],
#  'JONES ASHLEY MARIE': ['17 AGATHA ST'],
#  'CORNWELL MARISSA L': ['21 AGATHA ST'],
#  'NERIS NILDA': ['26 AGATHA ST'],
#  'NERIS FRANCISCO': ['26 AGATHA ST'],
#  'NERIS JOANNA': ['26 AGATHA ST'],
#  'VASQUEZ AARON': ['26 AGATHA ST'],
#  'AGUAOUZ ABDEL K': ['27 AGATHA ST'],
#  'AGUAOUZ BOUCHRA': ['27 AGATHA ST'],
#  'HARROUCHI AICHA': ['27 AGATHA ST'],
#  'AGUAOUZ AMIRA S': ['27 AGATHA ST'],
#  'ROSADO RAMON L': ['29 AGATHA ST'],
#  'CERRATO DIMAS O': ['1 AGAWAM ST'],
#  'RIANI ASMAA': ['1 AGAWAM ST'],
#  'AITELHADJ TOURIYA': ['4 AGAWAM ST'],
#  'AGUILAR RAUL': ['5 AGAWAM ST'],
#  'LEMUS-AGUILAR GUMERCINDA': ['5 AGAWAM ST'],
#  'AVALOS CARLOS E': ['7 AGAWAM ST'],
#  'FABIAN-MARTIN JERONIMO': ['11 AGAWAM ST'],
#  'LONDONO JHON A': ['11 AGAWAM ST'],
#  'NO RODAS NORMA R': ['11 AGAWAM ST'],
#  'MUNETON ELIANA M': ['11 AGAWAM ST'],
#  'VETRANO NANCY R': ['34 AGAWAM ST'],
#  'SCAFATI JENNIFER L': ['34 AGAWAM ST'],
#  'DIGIANVITTORIO DANIEL J': ['34 AGAWAM ST'],
#  'NAPOLI VICTORIA ANN': ['34 AGAWAM ST'],
#  'RAMCHARAN ANCILLA': ['39 AGAWAM ST'],
#  'RAMCHARAN ALISTAIR JASON': ['39 AGAWAM ST'],
#  'RAMCHARAN ANDREW T': ['39 AGAWAM ST'],
#  'RAMCHARAN JENNIFER M': ['39 AGAWAM ST'],
#  'VIANA KAROLINE C': ['47 AGAWAM ST'],
#  'VIANA WENDEL R': ['47 AGAWAM ST'],
#  'CORBELLE KACIE E': ['50 AGAWAM ST'],
#  'CORBELLE DONALD W': ['50 AGAWAM ST'],
#  'CORBELLE DEBORAH A': ['50 AGAWAM ST'],
#  'CORBELLE KELLI L': ['50 AGAWAM ST'],
#  'CORBELLE KARA MARIE': ['50 AGAWAM ST'],
#  'CORBELLE DONALD HENRY': ['50 AGAWAM ST'],
#  'TUSA ANTHONY P': ['51 AGAWAM ST'],
#  'GIANNETTA LORI': ['51 AGAWAM ST'],
#  'CIFUENTES ISAIAS': ['52 AGAWAM ST'],
#  'VELAZQUEZ JOSE': ['52 AGAWAM ST'],
#  'CIFUENTES MORENA': ['52 AGAWAM ST'],
#  'CIFUENTE-PINEDA JOSUE A': ['52 AGAWAM ST'],
#  'NAIM JILALI': ['54 AGAWAM ST'],
#  'EMBIRIK KHADDOUJAH': ['54 AGAWAM ST'],
#  'NAIM ABDELGHANI': ['54 AGAWAM ST'],
#  'ZAIDI KHADIJA': ['54 AGAWAM ST'],
#  'MESNAOUI DOHA': ['54 AGAWAM ST'],
#  'SAHROUR NOUREDINE': ['56 AGAWAM ST'],
#  'SAHROUR ASMAA AZIZI': ['56 AGAWAM ST'],
#  'SAHROUR OMAR SLEEMAN': ['56 AGAWAM ST'],
#  'DICENSO RONALD A': ['59 AGAWAM ST'],
#  'DICENSO GINA M': ['59 AGAWAM ST'],
#  'DICENSO DEREK C': ['59 AGAWAM ST'],
#  'DICENSO JAGGER C': ['59 AGAWAM ST'],
#  'DICENSO RAQUEL-ALEXA': ['59 AGAWAM ST'],
#  'SHALEMO SAMUEL T': ['60 AGAWAM ST'],
#  'BIRHAN NEKATIBEB': ['62 AGAWAM ST'],
#  'BATYDANG ABEBA': ['62 AGAWAM ST'],
#  'SILBURN FELIANN A': ['62 AGAWAM ST'],
#  'MORGAN DOROTHY PAGE': ['5 AGNEOUS AVE'],
#  'MORGAN MICHAEL A': ['5 AGNEOUS AVE'],
#  'VERRILL KAREN M': ['9 AGRY TER'],
#  'DESHAIES RICHARD': ['16 AGRY TER'],
#  'SILUE KOLOTIOLOMA': ['16 AGRY TER'],
#  'SILUE MEFONGA AWA': ['16 AGRY TER'],
#  'SAVANE MAGBE': ['16 AGRY TER'],
#  'ORILEY REGINA M': ['17 AGRY TER'],
#  'CORRADO ANGELINA A': ['17 AGRY TER'],
#  'MCDONALD SHARON M': ['17 AGRY TER'],
#  'WILLIS HELEN': ['17 AGRY TER'],
#  'MCDONALD PATRICK J': ['17 AGRY TER'],
#  'MAGUIRE MARY A': ['9 ALBERT AVE'],
#  'HARVEY SUZANNE JAYNE': ['9 ALBERT AVE'],
#  'VALENTINI GIOVANNA': ['14 ALBERT AVE'],
#  'BRITO ANANIAS G': ['15 ALBERT AVE'],
#  'BAPTISTA LAURA': ['15 ALBERT AVE'],
#  'VALENTINI-BRITO MARIA V': ['15 ALBERT AVE'],
#  'BRITO CHRISTIAN': ['15 ALBERT AVE'],
#  'BRITO BRENDON': ['15 ALBERT AVE'],
#  'GALVEZ MEDARDO': ['15 ALBERT AVE'],
#  'ARISMENDY LUZ E': ['15 ALBERT AVE'],
#  'BELCAID KHALIL': ['16 ALBERT AVE'],
#  'LAFONTAINE REINA JANETH': ['21 ALBERT AVE'],
#  'LAFONTAINE PIERRE D': ['21 ALBERT AVE'],
#  'AGUILERA AGUILAR CLAUDIO': ['21 ALBERT AVE'],
#  'OQUELI SKARLETH M': ['21 ALBERT AVE'],
#  'MARTINEZ MARLON H': ['21 ALBERT AVE'],
#  'MARTINEZ MEXULLAN': ['21 ALBERT AVE'],
#  'MCLAUGHLIN JENNIFER LYN': ['21 ALBERT AVE'],
#  'KIELPINSKI JESSIE M': ['5 ALDEN AVE'],
#  'BAMBERG ROBERT P': ['8 ALDEN AVE'],
#  'SISSON ROBIN M': ['12 ALDEN AVE'],
#  'BOSCO JOANNE B': ['15 ALDEN AVE'],
#  'BOSCO JOSHUA J': ['15 ALDEN AVE'],
#  'BOSCO JESSE BIRD': ['15 ALDEN AVE'],
#  'BOSCO JULIA ROSE': ['15 ALDEN AVE'],
#  'RONGA GLORIA': ['16 ALDEN AVE'],
#  'RONGA VANESSA': ['16 ALDEN AVE'],
#  'RONGA ERICA': ['16 ALDEN AVE'],
#  'PULISCIANO ALAN J': ['21 ALDEN AVE'],
#  'AUSTIN MARGARET': ['21 ALDEN AVE'],
#  'FEDOROVA SVETLANA': ['22 ALDEN AVE'],
#  'BOGUSLAVSKIY EVGUENI A': ['22 ALDEN AVE'],
#  'MUTCHLER TRENT P': ['25 ALDEN AVE'],
#  'QING-KEATING LILY': ['25 ALDEN AVE'],
#  'FARINELLA ROSS C': ['25 ALDEN AVE'],
#  'FARINELLA MELISSA A': ['25 ALDEN AVE'],
#  'BARMAKI LAMYAA S': ['26 ALDEN AVE'],
#  'ADAMS ELEANOR F': ['29 ALDEN AVE'],
#  'DIGIANNI JOSEPH J': ['30 ALDEN AVE'],
#  'RHODENIZER RACQUEL ANNE': ['30 ALDEN AVE'],
#  'SOLEMINA DAVID J': ['33 ALDEN AVE'],
#  'SOLEMINA LISA M': ['33 ALDEN AVE'],
#  'FIGUEROA DENISE': ['37 ALDEN AVE'],
#  'DEAGLE DEBRA A': ['37 ALDEN AVE'],
#  'CHRISTOPHER LAWRENCE J': ['41 ALDEN AVE', '97 EUSTIS ST'],
#  'CHRISTOPHER RACHEL H': ['41 ALDEN AVE'],
#  'CHRISTOPHER BRENDAN M': ['41 ALDEN AVE'],
#  'SIMS ROBERT JOSEPH': ['44 ALDEN AVE'],
#  'CALDEN JENNIFER MARIE': ['44 ALDEN AVE'],
#  'MOSCHELLA PATRICIA A': ['45 ALDEN AVE'],
#  'MOSCHELLA KEVIN C': ['45 ALDEN AVE'],
#  'CITINO RICHARD J': ['50 ALDEN AVE'],
#  'BEARDSLEY KENNETH MICHAEL': ['54 ALDEN AVE'],
#  'BEARDSLEY LINDA V': ['54 ALDEN AVE'],
#  'PERGOLA ROBIN A': ['55 ALDEN AVE'],
#  'CLARK BRENDA': ['55 ALDEN AVE'],
#  'PERGOLA JAMES M': ['55 ALDEN AVE'],
#  'PERGOLA PAIGE M': ['55 ALDEN AVE'],
#  'PERGOLA JAIDE M': ['55 ALDEN AVE'],
#  'PERGOLA MATTHEW M': ['55 ALDEN AVE'],
#  'FARRELL SHEILA R': ['56 ALDEN AVE'],
#  'EPSIMOS EDNA M': ['57 ALDEN AVE'],
#  'ESPARZA ADAN': ['61 ALDEN AVE'],
#  'BUENROSTRO SILVIA': ['61 ALDEN AVE'],
#  'ESPARZA ALANDRA': ['61 ALDEN AVE'],
#  'DUFF DIANNE': ['65 ALDEN AVE'],
#  'DUFF ASHLEY': ['65 ALDEN AVE'],
#  'DUFF BRITTANY L': ['65 ALDEN AVE'],
#  'PINEDA ABRAHAM A': ['69 ALDEN AVE'],
#  'NUFIO ELVA L': ['69 ALDEN AVE'],
#  'BRASSIL JAMES R': ['73 ALDEN AVE'],
#  'MCKAY SANDRA A': ['73 ALDEN AVE'],
#  'GLISERMAN GAIL C': ['74 ALDEN AVE'],
#  'STRINGI DAVID ANTHONY': ['76 ALDEN AVE'],
#  'MAGGIO MARGARET M': ['76 ALDEN AVE'],
#  'SANDERS REGINA': ['6 ALICE ST'],
#  'ALVARADO DELWIN A': ['11 ALICE ST'],
#  'ALVARADO DAZLEE A': ['11 ALICE ST'],
#  'FITZPATRICK CORNELIUS J': ['12 ALICE ST'],
#  'WATSON CAROL A': ['15 ALICE ST'],
#  'SABER ABDERRAHMANE': ['18 ALICE ST'],
#  'BONILLA ANA': ['19 ALICE ST'],
#  'HERNANDEZ JULIO E': ['19 ALICE ST'],
#  'HERNANDEZ ERIKA Y': ['19 ALICE ST'],
#  'COGGSWELL MARY': ['20 ALICE ST'],
#  'CHERRY JEFFREY RYNE': ['22 ALICE ST'],
#  'MELCHER ALEX J': ['22 ALICE ST'],
#  'ALARCON ISABEL': ['25 ALICE ST'],
#  'LEGUISAMON WALLIS M': ['25 ALICE ST'],
#  'MOJICA FREDDIE': ['25 ALICE ST'],
#  'PISATURO MASSIMINA': ['27 ALICE ST'],
#  'ZINAOUI FATIMA': ['28 ALICE ST'],
#  'EL ATRASSI SIDI BOUCHAIB': ['28 ALICE ST'],
#  'MOREIRA JEFFERSON S': ['32 ALICE ST'],
#  'MOREIRA CLAUDIA CRUZ': ['32 ALICE ST'],
#  'GOUVEIA JOSEPH': ['35 ALICE ST'],
#  'SINE MARY M': ['37 ALICE ST'],
#  'KASINOWICZ CHRISTINE M': ['8 ALLSTON ST'],
#  'CRUZ IRIS A': ['14 ALLSTON ST'],
#  'PEGUERO ELVIS J': ['14 ALLSTON ST'],
#  'SILVA RICHARD C': ['14 ALLSTON ST'],
#  'SILVA GARCIA BRENDA A': ['14 ALLSTON ST'],
#  'PEREZ TORRES JONATHAN': ['14 ALLSTON ST'],
#  'MEDINA RUIZ AGIE CAROLINA': ['22 ALLSTON ST'],
#  'GONZALES DIEGO A': ['22 ALLSTON ST'],
#  'MOYA MARIA ISABEL': ['22 ALLSTON ST'],
#  'OLIVA BETTINA C': ['24 ALLSTON ST'],
#  'MUNOZ CARLOS M': ['24 ALLSTON ST'],
#  'RODRIGUEZ MARIA': ['28 ALLSTON ST'],
#  'AMAYA CARLOS A': ['28 ALLSTON ST'],
#  'RODRIGUEZ MARIA A': ['28 ALLSTON ST'],
#  'ARGUETA OSCAR AGUIRRE': ['32 ALLSTON ST'],
#  'ARGUETA MAYRA': ['32 ALLSTON ST'],
#  'ARGUETA BRIAN A': ['32 ALLSTON ST'],
#  'ARGUETA OSCAR E': ['32 ALLSTON ST'],
#  'ARGUETA JOSELINE': ['32 ALLSTON ST'],
#  'TARASKIEWICZ ARLENE B': ['36 ALLSTON ST'],
#  'BERTOCCHI BENAE M': ['36 ALLSTON ST'],
#  'BERTOCCHI DANIEL J': ['36 ALLSTON ST'],
#  "D'EON MARIE L": ['40 ALLSTON ST'],
#  'WHITE ROBERT F': ['40 ALLSTON ST'],
#  'DIROCCO-MERRITT GINA': ['40 ALLSTON ST'],
#  'NICOSIA LORENZO': ['44 ALLSTON ST'],
#  'NICOSIA MAUREEN': ['44 ALLSTON ST'],
#  'PORTILLO GABRIEL': ['44 ALLSTON ST'],
#  'SCHEPICI-PORTILLO AMANDA JOY': ['44 ALLSTON ST'],
#  'NICOSIA MICHAEL L': ['44 ALLSTON ST'],
#  'VALDEZ JOSE J': ['48 ALLSTON ST'],
#  'VALLEJO SANDRA': ['48 ALLSTON ST'],
#  'MORADEL-DEMENCIA VICTORINA': ['48 ALLSTON ST'],
#  'MENCIA JACOB': ['48 ALLSTON ST'],
#  'MARGARY VALDEZ': ['48 ALLSTON ST'],
#  'HEGNER NICOLE': ['52 ALLSTON ST'],
#  'HEGNER NICHOLAS': ['52 ALLSTON ST'],
#  'WHITEHEAD CALVIN D': ['56 ALLSTON ST'],
#  'FRANCOIS-LETANG ROSE': ['56 ALLSTON ST'],
#  'LOUIS-JEAN MOUDLEY': ['56 ALLSTON ST'],
#  'LOUIS-JEAN ANGELE L': ['56 ALLSTON ST'],
#  'SPELLEN MARC ANTHONY': ['63 ALLSTON ST'],
#  'CROWLEY MATTHEW P': ['63 ALLSTON ST'],
#  'MEARA ROBERT M': ['15 AMASA ST'],
#  'FLYNN TERENCE J': ['15 AMASA ST'],
#  'FLYNN VIRGINIA A': ['15 AMASA ST'],
#  'BUCCI CHRISTOPHER A': ['45 AMASA ST'],
#  'DURBANO DIANA': ['45 AMASA ST'],
#  'FONSECA RODRIGO': ['1 AMBROSE ST'],
#  'FONSECA ROSA': ['1 AMBROSE ST'],
#  'FONSECA NORMA': ['1 AMBROSE ST'],
#  'LOPEZ JOSE R': ['3 AMBROSE ST'],
#  'GIANGREGORIO RAFFAELLA': ['3 AMBROSE ST'],
#  'IASBARRONE GEORGE W': ['9 AMBROSE ST'],
#  'IASBARRONE JUDITH A': ['9 AMBROSE ST'],
#  'IASBARRONE GEORGE': ['9 AMBROSE ST'],
#  'IASBARRONE DANIELLE L': ['9 AMBROSE ST'],
#  'IASBARRONE NANCY MAE': ['9 AMBROSE ST'],
#  'LINARES DELIA MARITZA': ['10 AMBROSE ST'],
#  'RECAREY JAIME': ['10 AMBROSE ST'],
#  'TORRES RONALD F': ['11 AMBROSE ST'],
#  'DELEON PEDRO PABLO': ['11 AMBROSE ST'],
#  'SASSO JACQUELINE A': ['15 AMBROSE ST'],
#  'GUARINO LAWRENCE J': ['15 AMBROSE ST'],
#  'SULLIVAN EDWARD S': ['17 AMBROSE ST'],
#  'PEREZ ISABEL M': ['17 AMBROSE ST'],
#  'OCHOA CARLOS H': ['22 AMBROSE ST'],
#  'MARTINEZ JULIO J': ['22 AMBROSE ST'],
#  'GUEVARA NOEMI C': ['22 AMBROSE ST'],
#  'MARTINEZ MADELIN N': ['22 AMBROSE ST'],
#  'MARTINEZ JAIME V': ['22 AMBROSE ST'],
#  'MARTINEZ JENNIFER': ['22 AMBROSE ST', '47 IRVING ST'],
#  'IACOVIELLO FRANK': ['23 AMBROSE ST', '40 PHILOMENA AVE'],
#  'IACOVIELLO SANDRA': ['23 AMBROSE ST'],
#  'IACOVELLO NATASHA': ['23 AMBROSE ST'],
#  'GILLEBERTO HELENA': ['25 AMBROSE ST'],
#  'LAWLEY KAREN L': ['25 AMBROSE ST'],
#  'VALDEZ HERNANDEZ ANDREA DEJESUS J': ['26 AMBROSE ST'],
#  'PEREZ DOMINGO A': ['26 AMBROSE ST'],
#  'LOPEZ ANTONIO O': ['26 AMBROSE ST'],
#  'GUZMAN DE LOPEZ MARIA E': ['26 AMBROSE ST'],
#  'SANCHEZ PEREZ ARIANNY R': ['26 AMBROSE ST'],
#  'MUNGUIA JOSE ABILIO': ['28 AMBROSE ST'],
#  'MUNGUIA JOSE A': ['28 AMBROSE ST'],
#  'DIAZ ANA M': ['28 AMBROSE ST'],
#  'HERNANDEZ ANA M': ['28 AMBROSE ST'],
#  'MUNGUIA DAVID A': ['28 AMBROSE ST'],
#  'CUSHING STEPHEN H': ['30 AMBROSE ST'],
#  'MORIGERATO NANCY L': ['33 AMBROSE ST'],
#  'CIULLA JESSE L': ['33 AMBROSE ST'],
#  'BROWN YVONNE E': ['39 AMBROSE ST'],
#  'FALZARANO LOUIS E': ['41 AMBROSE ST'],
#  'SILVA JANINE MARIE': ['41 AMBROSE ST'],
#  "D'AMATO NICOLE": ['41 AMBROSE ST', '510 REVERE BEACH BLVD'],
#  'FALZARANO TONI A': ['41 AMBROSE ST'],
#  'DEASY-BOCCHINO IRENE G': ['43 AMBROSE ST'],
#  'LAM THUAN N': ['44 AMBROSE ST'],
#  'LAM NGOCMAI': ['44 AMBROSE ST'],
#  'GRAY PATRICIA S': ['47 AMBROSE ST'],
#  'GRAY RITA M': ['47 AMBROSE ST'],
#  'FLEMMING BAYLEE G': ['47 AMBROSE ST'],
#  'VILLANUEVA MARVIN D': ['50 AMBROSE ST'],
#  'MARTINEZ DE VILLANUEVA ROSA I': ['50 AMBROSE ST'],
#  'RIVERA VANESSA': ['50 AMBROSE ST'],
#  'GOMEZ GRACE': ['50 AMBROSE ST'],
#  'DIAZ SUMAYA': ['53 AMBROSE ST'],
#  'MOLINA JIMMY J': ['53 AMBROSE ST'],
#  'VICENTE JO-ANN': ['53 AMBROSE ST'],
#  'MOLINA CARLOS X': ['53 AMBROSE ST'],
#  'COLON ROSALINA': ['55 AMBROSE ST'],
#  'CONCEPCION YANIRA MARIE': ['55 AMBROSE ST'],
#  'PACE MITCHELL': ['56 AMBROSE ST'],
#  'PACE KENNETH D': ['56 AMBROSE ST'],
#  'SPINA SAMUEL PETER': ['56 AMBROSE ST'],
#  'DOHERTY PETER A': ['56 AMBROSE ST'],
#  'ALVES MARIANY P': ['57 AMBROSE ST'],
#  'SOBRINHO FRANCISCO A': ['57 AMBROSE ST'],
#  'ALVES ALBA VP': ['57 AMBROSE ST'],
#  'ROCHA-SAAR MARCIA P': ['57 AMBROSE ST'],
#  'ALVES MARCOS': ['57 AMBROSE ST'],
#  'SPERA TERESA M': ['59 AMBROSE ST'],
#  'MEADOWCROFT MARC PETER': ['59 AMBROSE ST'],
#  'NORCOTT WILLIAM J': ['61 AMBROSE ST'],
#  'NORCOTT DEBORAH E': ['61 AMBROSE ST'],
#  'DEFRONZO MARINA': ['63 AMBROSE ST'],
#  'CARDONA JASON C': ['63 AMBROSE ST'],
#  'DZUZDANOVIC MUHAMED': ['63 AMBROSE ST'],
#  'AGUIRRE ASDRUBAL': ['67 AMBROSE ST'],
#  'LAGORIO CORINNE M': ['70 AMBROSE ST'],
#  'PASTORE LINDA D': ['71 AMBROSE ST'],
#  'SCOPPA SUSAN A': ['76 AMBROSE ST'],
#  'WELLS MICHAEL S': ['76 AMBROSE ST'],
#  'WELLS JOAN': ['76 AMBROSE ST'],
#  'WELLS MACKENZIE E': ['76 AMBROSE ST'],
#  'MORALES DORIS D': ['82 AMBROSE ST'],
#  'MATHER ELIZABETH VICTORIA': ['82 AMBROSE ST'],
#  'MORALES ANA C': ['84 AMBROSE ST'],
#  'MORALES ELIZABETH': ['84 AMBROSE ST'],
#  'SALAZAR CHRISTIAN SHAMIR': ['84 AMBROSE ST'],
#  'RODRIGUEZ LUIS J': ['88 AMBROSE ST'],
#  'CHEA SOPHEA': ['88 AMBROSE ST'],
#  'ROS SAMNANG': ['92 AMBROSE ST'],
#  'ROS MICHELLE ELYSE': ['92 AMBROSE ST'],
#  'CATALDO GENNARO L': ['6 AMELIA PL'],
#  'CATALDO ROSETTE M': ['6 AMELIA PL'],
#  'MAHARJAN BISHWO': ['14 AMELIA PL'],
#  'MAHARJAN MIRA': ['14 AMELIA PL'],
#  'ROSA ZINA MARIA': ['14 AMELIA PL'],
#  'LACERDA QUEZIA R': ['14 AMELIA PL'],
#  'LAURIA MARYLOU': ['19 AMELIA PL'],
#  'LACIVITA NANCY L': ['22 AMELIA PL'],
#  'MANISCALCO ACCURZIO': ['25 AMELIA PL'],
#  'MANISCALCO JEANNINE C': ['25 AMELIA PL'],
#  'LUSTENBERGER ANNETTE F': ['25 AMELIA PL'],
#  'RISTINO JUDITH A': ['30 AMELIA PL'],
#  'RISTINO JOSEPH JC': ['30 AMELIA PL'],
#  'RISTINO JOSEPH G': ['30 AMELIA PL'],
#  'FABIANO HOPE': ['30 AMELIA PL'],
#  'PIZZANO ALFRED': ['35 AMELIA PL'],
#  'PIZZANO ELAINE MARIE': ['35 AMELIA PL'],
#  'HINOJOSA MICHAEL': ['37 AMELIA PL'],
#  'HINOJOSA MARIEELENA': ['37 AMELIA PL'],
#  'HINOJOSA CHRISTOPHER': ['37 AMELIA PL'],
#  'HINOJOSA ALLY': ['37 AMELIA PL'],
#  'CATALLO STEPHEN C': ['38 AMELIA PL'],
#  'CATALLO LUCILLE M': ['38 AMELIA PL'],
#  'LOPILATO MICHAEL A': ['46 AMELIA PL'],
#  'LOPILATO ANTHONY F': ['46 AMELIA PL'],
#  'LOPILATO MARILYN R': ['46 AMELIA PL'],
#  'RUSSO CAROL A': ['54 AMELIA PL'],
#  'PINI GERALD A': ['54 AMELIA PL'],
#  'RUSSO JOAN M': ['54 AMELIA PL'],
#  'MARINO JEAN C': ['54 AMELIA PL'],
#  'RUSSO JOSEPHINE P': ['54 AMELIA PL'],
#  'LOCHIATTO LOUISE': ['66 AMELIA PL'],
#  'ROMANO DARIA L': ['66 AMELIA PL'],
#  'ROMANO KURT C': ['66 AMELIA PL'],
#  'ROMANO ALEXANDER K': ['66 AMELIA PL'],
#  'SPEZIALE GINA': ['70 AMELIA PL'],
#  'COHEN VALENTINA N': ['73 AMELIA PL'],
#  'GORHAM MICHAEL F': ['73 AMELIA PL'],
#  'GORHAM TANYA H': ['73 AMELIA PL'],
#  'COHEN LEA': ['73 AMELIA PL'],
#  'COHEN MONIQUE': ['73 AMELIA PL'],
#  'CIANO CORINNE': ['80 AMELIA PL'],
#  'CIANO ANTHONY': ['80 AMELIA PL'],
#  'HEARD WENDELL R': ['80 AMERICAN LEGION HWY'],
#  'KING ADRIAN S': ['80 AMERICAN LEGION HWY'],
#  'WILLIAMS GAIL E': ['80 AMERICAN LEGION HWY'],
#  'MARTIN DAVID J': ['80 AMERICAN LEGION HWY'],
#  'MCALLISTER MARK': ['80 AMERICAN LEGION HWY'],
#  'DEYANE NOUREDDINE': ['240 AMERICAN LEGION HWY'],
#  'RAE AMY': ['244 AMERICAN LEGION HWY'],
#  'SUAZO ALEX D': ['244 AMERICAN LEGION HWY'],
#  'TRACY MICHAEL A': ['249 AMERICAN LEGION HWY'],
#  'TRACY NANCY M': ['249 AMERICAN LEGION HWY'],
#  'BOCCUZZI VITO F': ['256 AMERICAN LEGION HWY'],
#  'MARTINEZ SERGIO': ['298 AMERICAN LEGION HWY'],
#  'MENDEZ ESTER': ['298 AMERICAN LEGION HWY'],
#  'PERAZA HERIBERTO': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA JOSE M': ['298 AMERICAN LEGION HWY'],
#  'SUCHITE DE PERAZA EUFEMIA': ['298 AMERICAN LEGION HWY'],
#  'MORAN MARTHA D': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA ZULMA A': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA ELSY N': ['298 AMERICAN LEGION HWY'],
#  'SANCHEZ STEVEN ALEXANDER': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA-AGUILAR ZURIELLE A': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA-MORAN MARIO': ['298 AMERICAN LEGION HWY'],
#  'MESTANZA-MORAN MARTHA E': ['298 AMERICAN LEGION HWY'],
#  'FERULLO ANTHONY': ['304 AMERICAN LEGION HWY'],
#  'DAVIS DIANA M': ['304 AMERICAN LEGION HWY'],
#  'DAVIS MARGARET L': ['304 AMERICAN LEGION HWY'],
#  'CORDWELL-RIZZO ROSALIE': ['310 AMERICAN LEGION HWY'],
#  'MEJIA DENNIS': ['320 AMERICAN LEGION HWY'],
#  'CERMINARA ANTHONY J': ['324 AMERICAN LEGION HWY'],
#  'GUTIERREZ MIRSA ESTEFANY': ['324 AMERICAN LEGION HWY'],
#  'BLANCO LEDY D': ['330 AMERICAN LEGION HWY'],
#  'BLANCO KAREN T': ['330 AMERICAN LEGION HWY'],
#  'GOMES SANDRA A': ['332 AMERICAN LEGION HWY'],
#  'APARICIO ANA B': ['334 AMERICAN LEGION HWY'],
#  'CHICAS CESAR A': ['334 AMERICAN LEGION HWY'],
#  'OCHOA JOAO FABIO': ['334 AMERICAN LEGION HWY'],
#  'CHICAS FERNANDA G': ['334 AMERICAN LEGION HWY'],
#  'KATICA ALIJA': ['340 AMERICAN LEGION HWY'],
#  'KATICA ADISA': ['340 AMERICAN LEGION HWY'],
#  'OUAKANI LEKBIR': ['437 AMERICAN LEGION HWY'],
#  'BOUBAKRAOUY SAMIRA': ['437 AMERICAN LEGION HWY'],
#  'PAOLINI ANTHONY': ['453 AMERICAN LEGION HWY'],
#  'BATES MADONNA L': ['453 AMERICAN LEGION HWY'],
#  'QUEZADA DAVID E': ['453 AMERICAN LEGION HWY'],
#  'LATTANZI CELESTE': ['462 AMERICAN LEGION HWY'],
#  'COSCIA DONNA M': ['16 ANN RD'],
#  'SCANELLI ROBERT': ['17 ANN RD'],
#  'PFEIFER GERALDINE': ['24 ANN RD'],
#  'PFEIFER CARLTON A': ['24 ANN RD'],
#  'DESANTIS JAMES RICHARD': ['27 ANN RD'],
#  'DESANTIS JOSEPH A': ['27 ANN RD'],
#  'DESANTIS JOHN A': ['27 ANN RD'],
#  'DESANTIS JENAE': ['27 ANN RD'],
#  'FORNIA LYDIA': ['32 ANN RD'],
#  'BIRD JOSEPH T': ['32 ANN RD'],
#  'GRAVALLESE MICHAEL A': ['35 ANN RD'],
#  'GRAVALLESE CATHERINE A': ['35 ANN RD'],
#  'MACDONALD BRIAN J': ['35 ANN RD'],
#  'GRAVALLESE LYN': ['35 ANN RD'],
#  'FERNANDES ELEINE R': ['42 ANN RD'],
#  'GREGORIO CELESTE': ['45 ANN RD'],
#  'GREGORIO BRIANA': ['45 ANN RD'],
#  'DELGRECO-FICHERA JEANINE M': ['45 ANN RD'],
#  'FICHERA TIA LOREN': ['45 ANN RD'],
#  'DESANTIS FRANCES M': ['50 ANN RD'],
#  'CONSOLO LISA F': ['9 ARCADIA ST'],
#  'KRUSCHEWSKY LILIANA M': ['9 ARCADIA ST'],
#  'SULLIVAN PAUL L': ['9 ARCADIA ST'],
#  'MAZZOLA LAURA': ['9 ARCADIA ST'],
#  'CAPACHIETTI IDAJORON': ['14 ARCADIA ST'],
#  'HERNANDEZ JOSE I': ['14 ARCADIA ST'],
#  'HERNANDEZ YRANIA': ['14 ARCADIA ST'],
#  'LOUGHNER LIAM G': ['15 ARCADIA ST'],
#  'PUOPOLO ROBERT': ['20 ARCADIA ST'],
#  'SPONAGLE WILLIAM WAYNE': ['20 ARCADIA ST'],
#  'BOURZAK AICHA': ['22 ARCADIA ST'],
#  'BENAYAD CHAIMAA': ['22 ARCADIA ST'],
#  'KADDIOUI TOURIA': ['22 ARCADIA ST'],
#  'CHOURAK BOUCHAIB': ['22 ARCADIA ST'],
#  'RAMIREZ TRANSITO A': ['26 ARCADIA ST'],
#  'RUIZ SYLVIA': ['26 ARCADIA ST'],
#  'GRANITO NICHOLAS P': ['30 ARCADIA ST'],
#  'CHEESEMAN JOHN': ['30 ARCADIA ST'],
#  'SALIE JOHN H': ['31 ARCADIA ST'],
#  'WAREHAM JUNE M': ['31 ARCADIA ST'],
#  'OPUSTIL PAWEL J': ['35 ARCADIA ST'],
#  'LEWIS AVERY': ['38 ARCADIA ST'],
#  'WIXON CLARENCE M': ['38 ARCADIA ST'],
#  'WIXON DEBORAH': ['38 ARCADIA ST'],
#  'WIXON GAETANO N': ['38 ARCADIA ST'],
#  'FORD JESSI A': ['38 ARCADIA ST'],
#  'COLLAZO ANNIE M': ['40 ARCADIA ST'],
#  'RONDON MCCLELLAND C': ['42 ARCADIA ST'],
#  'RONDON LAUREN N': ['42 ARCADIA ST'],
#  'RONDON JOSHUA E': ['42 ARCADIA ST'],
#  'ALLEN JOSHUA D': ['45 ARCADIA ST'],
#  'OCONNOR ANDREW': ['45 ARCADIA ST'],
#  'AQUALANEY JENNIFER R': ['45 ARCADIA ST'],
#  'DASILVA TIANNA E': ['47 ARCADIA ST'],
#  'DESIMONE JOHNATHAN': ['47 ARCADIA ST'],
#  'RINALDI COREY R': ['48 ARCADIA ST'],
#  'TESTA MAUREEN E': ['50 ARCADIA ST'],
#  'TESTA JOSEPH A': ['50 ARCADIA ST'],
#  'LOMBARDO KALI A': ['51 ARCADIA ST'],
#  'PEREZ JOSE L': ['54 ARCADIA ST'],
#  'PEREZ ALIDA A': ['54 ARCADIA ST'],
#  'MACINNES CATHERINE ROSE': ['55 ARCADIA ST'],
#  'HOYSRADT PAMELA': ['55 ARCADIA ST'],
#  'ROSADO JON A': ['55 ARCADIA ST'],
#  'LONG AMMIE': ['56 ARCADIA ST'],
#  'LONG JACK': ['56 ARCADIA ST'],
#  'PEREZ JAZMIN A': ['56 ARCADIA ST'],
#  'LAWYER LESLIE J': ['58 ARCADIA ST'],
#  'GAUDIN CHRISTINA R': ['58 ARCADIA ST'],
#  'SCOTT JULIA M': ['59 ARCADIA ST'],
#  'HANSON DEBRA': ['59 ARCADIA ST'],
#  'COIMBRA EUDEVAN': ['66 ARCADIA ST'],
#  'MACHADO MARIA': ['66 ARCADIA ST'],
#  'MCGRORY ELLEN M': ['66 ARCADIA ST'],
#  'TOPPI SUSAN M': ['71 ARCADIA ST'],
#  'MCNAMARA DOROTHY': ['71 ARCADIA ST'],
#  'BENOIT RICHARD': ['71 ARCADIA ST'],
#  'OROZCO ENRIQUE G': ['71 ARCADIA ST'],
#  'DOLAN NANCY A': ['74 ARCADIA ST'],
#  'ROMERO MARCELINO': ['74 ARCADIA ST'],
#  'MERINO SOFIA': ['74 ARCADIA ST'],
#  'RAYMOND JUSTINE': ['74 ARCADIA ST'],
#  'ROMERO WILL A': ['74 ARCADIA ST'],
#  'LEVCHENKO BORIS': ['77 ARCADIA ST'],
#  'LEVCHENKO TATYANA': ['77 ARCADIA ST'],
#  'DELEARY RICHARD EARL': ['81 ARCADIA ST'],
#  'DELEARY ANNMARIE': ['81 ARCADIA ST'],
#  'WENTWORTH SALLY V': ['84 ARCADIA ST'],
#  'BROWN WENDY J': ['84 ARCADIA ST'],
#  'BROWN CHARLES E': ['84 ARCADIA ST'],
#  'ZENGA CHERYL CHRISTINE': ['87 ARCADIA ST'],
#  'ZENGA NICHOLAS M': ['87 ARCADIA ST'],
#  'ZOUHAIR DRISS': ['89 ARCADIA ST'],
#  'CHARLEBOIS JACQUELINE': ['89 ARCADIA ST'],
#  'BAOUSSOUH AZIZ': ['89 ARCADIA ST'],
#  'ZOUHAIR BOUCHRA': ['89 ARCADIA ST'],
#  'TAREK HAKINA': ['92 ARCADIA ST'],
#  'NEVEU RAYMOND P': ['92 ARCADIA ST'],
#  'NEVEU NICOLE M': ['92 ARCADIA ST'],
#  'CARDONA NELSON': ['94 ARCADIA ST'],
#  'SULLIVAN MAUREEN M': ['96 ARCADIA ST'],
#  'LANZA LORENA C': ['98 ARCADIA ST'],
#  'LANZA JOSEPH A': ['98 ARCADIA ST'],
#  'JOHNSON MARGARET A': ['99 ARCADIA ST'],
#  'PRIZIO CHERYL A': ['99 ARCADIA ST'],
#  'CRONIN STEPHEN NICHOLAS': ['100 ARCADIA ST'],
#  'ZIMMERMAN HUNTER A': ['100 ARCADIA ST'],
#  'SHKOZA PIRO': ['102 ARCADIA ST'],
#  'SHKOZA FLORIN': ['102 ARCADIA ST'],
#  'SHKOZA GERALD': ['102 ARCADIA ST'],
#  'SHKOZA ALVA': ['102 ARCADIA ST'],
#  'DESIMONE VICTOR': ['104 ARCADIA ST'],
#  'DESIMONE SHERI': ['104 ARCADIA ST'],
#  'DUARTE JOHN LENNON': ['11 ARCHER AVE'],
#  'CARRIERE BRITTANY M': ['11 ARCHER AVE'],
#  'STRELITZ ROBERT F': ['14 ARCHER AVE'],
#  'JENKINSON KATHRYN ANN': ['14 ARCHER AVE'],
#  'BRADLEY PAUL': ['17 ARCHER AVE'],
#  'BRADLEY BONNIE L': ['17 ARCHER AVE'],
#  'MAGANA JILLIAN A': ['17 ARCHER AVE'],
#  'MAGANA ARMANDO': ['17 ARCHER AVE'],
#  'RINALDI LISA': ['5 ARGYLE ST'],
#  'BURROW RODERICK R': ['5 ARGYLE ST'],
#  'RINALDI JOSEPH M': ['5 ARGYLE ST'],
#  'RINALDI AMBER E': ['5 ARGYLE ST'],
#  'DAO THANH VAN': ['12 ARGYLE ST'],
#  'PHAM HONG THI': ['12 ARGYLE ST'],
#  'SHAW DENNIS M': ['12 ARGYLE ST'],
#  'BRODERICK CHRISTINE L': ['15 ARGYLE ST'],
#  'MCMENAMIN DAVID J': ['16 ARGYLE ST'],
#  'HONOHAN JAMES J': ['17 ARGYLE ST'],
#  'HONOHAN MICHELE A': ['17 ARGYLE ST'],
#  'DEVEAU MELISSA R': ['17 ARGYLE ST'],
#  'ALCANTARA JULIO': ['23 ARGYLE ST'],
#  'ALCANTRA MARIA': ['23 ARGYLE ST'],
#  'GANOZA JOHNNY': ['23 ARGYLE ST'],
#  'SOLANO ESTRELLA': ['23 ARGYLE ST'],
#  'ALCANTARA EVELYN G': ['23 ARGYLE ST'],
#  'ALCANTARA GIANPIERE J': ['23 ARGYLE ST'],
#  'GANOZA NAHORY': ['23 ARGYLE ST'],
#  'LOPEZ MARIA J': ['27 ARGYLE ST'],
#  'LOPEZ JOSE A': ['27 ARGYLE ST'],
#  'LOPEZ RENE A': ['27 ARGYLE ST'],
#  'LOPEZ LUIS A': ['27 ARGYLE ST'],
#  'FLORES BELKI A': ['27 ARGYLE ST'],
#  'LOPEZ BERNARDO D': ['27 ARGYLE ST'],
#  'IRAHETA ROSA G': ['27 ARGYLE ST'],
#  'LOPEZ-IRAHETA ELIAS D': ['27 ARGYLE ST'],
#  'CHEN HAIXIONG': ['8 ARLINGTON AVE'],
#  'WU QINGHUA': ['8 ARLINGTON AVE'],
#  'HUIMING LI': ['8 ARLINGTON AVE'],
#  'LI DALING': ['8 ARLINGTON AVE'],
#  'CHEN AIZHEN': ['8 ARLINGTON AVE'],
#  'DANH PHON THI': ['14 ARLINGTON AVE'],
#  'DANH HANH': ['14 ARLINGTON AVE'],
#  'DANH HIEU MINH': ['14 ARLINGTON AVE'],
#  'DANH MYPHUNG': ['14 ARLINGTON AVE'],
#  'DANH PHUONG M': ['14 ARLINGTON AVE'],
#  'CHAU SANG': ['14 ARLINGTON AVE'],
#  'DIMARTINO PIETRINA': ['22 ARLINGTON AVE'],
#  'HOXHA LULZIM': ['22 ARLINGTON AVE'],
#  'HOXHA HYRIJE XIM': ['22 ARLINGTON AVE'],
#  'HOXHA AFRIM': ['22 ARLINGTON AVE'],
#  'PHAM BIEN CONG': ['22 ARLINGTON AVE'],
#  'PHAM ANNA': ['22 ARLINGTON AVE'],
#  'CORTAVE HECTOR O': ['25 ARLINGTON AVE'],
#  'SOLORZANO BRIAN J': ['25 ARLINGTON AVE'],
#  'CORTAVE KATHRYN M': ['25 ARLINGTON AVE'],
#  'LOPEZ YARIV': ['25 ARLINGTON AVE'],
#  'ARGUETA AGUIRRE JULIAN': ['26 ARLINGTON AVE'],
#  'ARGUETA AGUIRRE DILMA': ['26 ARLINGTON AVE'],
#  'REYES LOPEZ PEDRO': ['26 ARLINGTON AVE'],
#  'MEJIA-BETANCUR CRISTIAN O': ['26 ARLINGTON AVE'],
#  'KHOUBACH ELHACHM': ['26 ARLINGTON AVE'],
#  'AMGHAR KHADIJA': ['26 ARLINGTON AVE'],
#  'KHOUBACH RAJAA': ['26 ARLINGTON AVE'],
#  'KHOUBACH LATIFA': ['26 ARLINGTON AVE'],
#  'KHOUBACH IMANE': ['26 ARLINGTON AVE'],
#  'MORALES ANNETTE': ['28 ARLINGTON AVE'],
#  'LIMA MARIA': ['28 ARLINGTON AVE'],
#  'LIMA ANDREAS': ['28 ARLINGTON AVE'],
#  'WHITTAKER PAULA M': ['31 ARLINGTON AVE'],
#  'GRIECO CONCETTA': ['32 ARLINGTON AVE'],
#  'RUIZ NATALIA': ['38 ARLINGTON AVE'],
#  'RUIZ JULIAN': ['38 ARLINGTON AVE'],
#  'RUIZ LOPEZ KAREN': ['38 ARLINGTON AVE'],
#  'PEREZ LEONCIO ALBERTO': ['38 ARLINGTON AVE'],
#  'JARAMILLO OLGA CECILIA': ['38 ARLINGTON AVE'],
#  'PEREZ DIEGO LEON': ['38 ARLINGTON AVE'],
#  'PEREZ DAVID E': ['38 ARLINGTON AVE'],
#  'VILLADA KATHERINE': ['38 ARLINGTON AVE'],
#  'PEREZ JHON': ['38 ARLINGTON AVE'],
#  'MENDELSOHN JULIE': ['39 ARLINGTON AVE'],
#  'CROWE ROBERT JOSEPH': ['42 ARLINGTON AVE'],
#  'MAMBUCA MARILYN E': ['45 ARLINGTON AVE'],
#  'YAQOOB ROBYN L': ['46 ARLINGTON AVE'],
#  'YAQOOB MUHAMMAD': ['46 ARLINGTON AVE'],
#  'YAQOOB NYLA ELEANOR': ['46 ARLINGTON AVE'],
#  'YAQOOB ZEESHAN N': ['46 ARLINGTON AVE'],
#  'LAKACHA KRISTIN M': ['52 ARLINGTON AVE'],
#  'LAKACHA ELVIS': ['52 ARLINGTON AVE'],
#  'LAKACHA SELMA': ['52 ARLINGTON AVE'],
#  'LAKACHA AZRA': ['52 ARLINGTON AVE'],
#  'DAVIS ANGELA': ['55 ARLINGTON AVE'],
#  'DAVIS FRANCIS G': ['55 ARLINGTON AVE'],
#  'DAVIS HELEN M': ['55 ARLINGTON AVE'],
#  'RAMIREZ JOSE': ['66 ARLINGTON AVE', '74 HIGHLAND ST'],
#  'HURTADO-KHODIR BLANCA M': ['66 ARLINGTON AVE'],
#  'KHODIR MOHAMED A': ['66 ARLINGTON AVE'],
#  'AYLWARD BERTHA': ['66 ARLINGTON AVE'],
#  'HURTADO NESTOR DAVID': ['66 ARLINGTON AVE'],
#  'HURTADO EDUARDO': ['66 ARLINGTON AVE'],
#  'CIAMPA MICHAEL J': ['69 ARLINGTON AVE'],
#  'CIAMPA BRENDA L': ['69 ARLINGTON AVE'],
#  'CIAMPA ANTHONY': ['69 ARLINGTON AVE'],
#  'MEDINA JORGE': ['70 ARLINGTON AVE'],
#  'MEDINA PAULA ANDREA': ['70 ARLINGTON AVE'],
#  'BONILLA MARIA ZULMA': ['70 ARLINGTON AVE'],
#  'HENAO JOHNNY A': ['70 ARLINGTON AVE'],
#  'ALCANTAR ANTONIO': ['76 ARLINGTON AVE'],
#  'BUENROSTRO NORMA': ['76 ARLINGTON AVE'],
#  'ALCANTAR LUIS': ['76 ARLINGTON AVE'],
#  'ALCANTAR ABEL': ['76 ARLINGTON AVE'],
#  'ALCANTAR EMILY': ['76 ARLINGTON AVE'],
#  'JIMENEZ JUAN C': ['77 ARLINGTON AVE'],
#  'CORREA ADRIANA M': ['77 ARLINGTON AVE'],
#  'JIMENEZ ANGIE S': ['77 ARLINGTON AVE'],
#  'ROCHA JOSEPH H': ['82 ARLINGTON AVE'],
#  'CALDER CYNTHIA M': ['82 ARLINGTON AVE'],
#  'RUSSELL MASON': ['82 ARLINGTON AVE'],
#  'FELICE KELLY S': ['82 ARLINGTON AVE'],
#  'DUNKIN JAMES M': ['82 ARLINGTON AVE'],
#  'MONDELLO CARA': ['82 ARLINGTON AVE'],
#  'DIROSA WILLIAM N': ['82 ARLINGTON AVE'],
#  'DUNKIN MATTHEW M': ['82 ARLINGTON AVE'],
#  'RANDAZZO KYLE R': ['84 ARLINGTON AVE'],
#  'MESA JOAQUIN': ['85 ARLINGTON AVE'],
#  'FERNANDEZ V LORENA D': ['85 ARLINGTON AVE'],
#  'CARDONA LAURA': ['85 ARLINGTON AVE'],
#  'TESTA JOSEPH J': ['85 ARLINGTON AVE'],
#  'YEPEZ DIEGO': ['88 ARLINGTON AVE'],
#  'ERAZO MARYURY': ['88 ARLINGTON AVE'],
#  'YEPEZ ESTEBAN': ['88 ARLINGTON AVE'],
#  'ERAZO HAROL L': ['88 ARLINGTON AVE'],
#  'ERAZO ALBA L': ['88 ARLINGTON AVE'],
#  'TREJOS STEPHANNY': ['88 ARLINGTON AVE'],
#  'ARBOLEDA NATHALIA': ['88 ARLINGTON AVE'],
#  'CARDONA DIEGO M': ['88 ARLINGTON AVE'],
#  'CROSBY LYNNEA ANN': ['89 ARLINGTON AVE'],
#  'CARNEY DONNA A': ['89 ARLINGTON AVE'],
#  'DUNPHY SHAUN P': ['90 ARLINGTON AVE'],
#  'DUNPHY ERIN A': ['90 ARLINGTON AVE'],
#  'CARBONE PETER M': ['90 ARLINGTON AVE'],
#  'CARBONE PAULA': ['90 ARLINGTON AVE'],
#  'AZIZEDDINE MOHAMED': ['95 ARLINGTON AVE'],
#  'AZIZEDDINE BADRE': ['95 ARLINGTON AVE'],
#  'AZIZEDDINE MOUNA': ['95 ARLINGTON AVE'],
#  'LYONS JAYME LYNN': ['95 ARLINGTON AVE'],
#  'BENITEZ ALFARO SILVIA JEANNETTE': ['9 ARNOLD ST'],
#  'PACHECO SANTOS GIOVANNI ALEXANDER': ['9 ARNOLD ST'],
#  'PETROZZELLI ANTHONY': ['12 ARNOLD ST'],
#  'PETROZZELLI JUDITH': ['12 ARNOLD ST'],
#  'PETROZZELLI JAMES P': ['12 ARNOLD ST'],
#  'PETROZZELLI HAYLEY N': ['12 ARNOLD ST'],
#  'PEDRO MARYELLEN': ['14 ARNOLD ST'],
#  'MCCARRON JAMES J': ['18 ARNOLD ST'],
#  'MCCARRON ROBIN M': ['18 ARNOLD ST'],
#  'MCCARRON KAYLA A': ['18 ARNOLD ST'],
#  'MCCARRON JAMES MICHAEL': ['18 ARNOLD ST'],
#  'AGUILAR JUAN A': ['21 ARNOLD ST'],
#  'CARBAJALES MARIA': ['21 ARNOLD ST'],
#  'RIVAS NANCY': ['21 ARNOLD ST'],
#  'CURRAN JOHN J': ['21 ARNOLD ST'],
#  'CURRAN JAMES H': ['21 ARNOLD ST'],
#  'GAUDET ANNETTE M': ['23 ARNOLD ST'],
#  'ZOLA JOSEPH P': ['23 ARNOLD ST'],
#  'CIMINO ANTONIO': ['25 ARNOLD ST'],
#  'CIMINO MARIE ROBIN': ['25 ARNOLD ST'],
#  'PITRONE ADRIANA MARIE': ['25 ARNOLD ST'],
#  'PITRONE JEFFREY NICHOLAS': ['25 ARNOLD ST'],
#  'CIMINO ALANDRIA C': ['25 ARNOLD ST'],
#  'CIMINO ANGELICA': ['25 ARNOLD ST'],
#  'KELTER V RICHARD': ['26 ARNOLD ST'],
#  'HOGAN BRIANNA ALEXIS': ['26 ARNOLD ST'],
#  'GRAHAM DANIEL R': ['26 ARNOLD ST'],
#  'ANDERSON GAIL M': ['26 ARNOLD ST'],
#  'ANDERSON TYLER R': ['26 ARNOLD ST'],
#  'ANDERSON GRACE ASHLEY': ['26 ARNOLD ST'],
#  'ANDERSON JUSTIN ALEXANDER': ['26 ARNOLD ST'],
#  'REYES ELMER L': ['28 ARNOLD ST'],
#  'DIAZ MARIA A': ['28 ARNOLD ST'],
#  'ACOSTA WILLIAM E': ['28 ARNOLD ST'],
#  'DIAZ LINDA M': ['28 ARNOLD ST'],
#  'RICHMAN CARLA M': ['29 ARNOLD ST'],
#  'ALBANESE SABINO': ['30 ARNOLD ST'],
#  'ALBANESE MARGHERITA': ['30 ARNOLD ST'],
#  'MONTERO EVERARDO': ['34 ARNOLD ST'],
#  'MONTERO FELICITA': ['34 ARNOLD ST'],
#  'MONTERO GRACE C': ['34 ARNOLD ST'],
#  'DEMELO ADINILSON': ['37 ARNOLD ST'],
#  'DEMELO ROSIANE N': ['37 ARNOLD ST'],
#  'RHOADES DEBRA B': ['40 ARNOLD ST'],
#  'EBERHARDT SHAWN M': ['40 ARNOLD ST'],
#  'EBERHARDT KATIE LYN': ['40 ARNOLD ST'],
#  'PINTO BEVERLY F': ['42 ARNOLD ST'],
#  'PINTO JAMES R': ['42 ARNOLD ST'],
#  'PINTO JAMIE R': ['42 ARNOLD ST'],
#  'DEMASI THERESA J': ['46 ARNOLD ST'],
#  'DEMASI JOHN P': ['46 ARNOLD ST'],
#  'KING DENISE M': ['49 ARNOLD ST'],
#  'THEODORE LOUIS P': ['50 ARNOLD ST'],
#  'STDIC YVETTE': ['50 ARNOLD ST'],
#  'THEODORE DAFNEY': ['50 ARNOLD ST'],
#  'RODRIGUEZ TOMAS': ['55 ARNOLD ST'],
#  'RODRIGUEZ ELBA': ['55 ARNOLD ST'],
#  'FOX JAMES L': ['56 ARNOLD ST'],
#  'THOMAS-FOX MARTINE A': ['56 ARNOLD ST'],
#  'RICHARDS MARINA R': ['60 ARNOLD ST'],
#  'PESCE MICHAEL A': ['60 ARNOLD ST', '30 HARRINGTON ST'],
#  'PESCE CARMELLA N': ['60 ARNOLD ST'],
#  'FRANIS ABDERRAHIM': ['66 ARNOLD ST'],
#  'SAID FATIMA': ['66 ARNOLD ST'],
#  'TERRON MARIA L': ['70 ARNOLD ST'],
#  'PANZINI ROBIN M': ['80 ARNOLD ST'],
#  'PANZINI MATTHEW': ['80 ARNOLD ST'],
#  'PANZINI CHRISTOPHER M': ['80 ARNOLD ST'],
#  'FOLGORE PASQUALE': ['84 ARNOLD ST'],
#  'FOLGORE ROSELLA': ['84 ARNOLD ST'],
#  'LALLY MARIANNE': ['84 ARNOLD ST'],
#  'DEMINIE DIANE M': ['93 ARNOLD ST'],
#  'FERNANDEZ MICHELLE RUBY': ['93 ARNOLD ST'],
#  'DEMINIE PATRICIA R': ['93 ARNOLD ST'],
#  'DEMINIE JOHN PAUL': ['93 ARNOLD ST'],
#  'BARRY KASSANDRA': ['93 ARNOLD ST'],
#  'DEMINIE JENNA M': ['93 ARNOLD ST'],
#  'CANON LUZ M': ['101 ARNOLD ST'],
#  'LOKRITI FAKHREDDINE': ['109 ARNOLD ST'],
#  'TENTAS GEORGIA': ['109 ARNOLD ST'],
#  'SANTOSTEFANO JOANNE': ['111 ARNOLD ST'],
#  'DIGIULIO DEBRA A': ['119 ARNOLD ST'],
#  'DIGIULIO BENJAMIN PETER': ['119 ARNOLD ST'],
#  'REYES ANA A': ['120 ARNOLD ST'],
#  'REGA MARILU H': ['120 ARNOLD ST'],
#  'REGA JAN H': ['120 ARNOLD ST'],
#  'VILLAJULCA FELIPE A': ['120 ARNOLD ST'],
#  'EGE THOMAS J': ['123 ARNOLD ST'],
#  'EGE ANNMARIE': ['123 ARNOLD ST'],
#  'TRICKETT SUSAN': ['128 ARNOLD ST'],
#  'CAMPOS CARLOS O': ['137 ARNOLD ST'],
#  'BURGESS LAURA L': ['137 ARNOLD ST'],
#  'TORRA-CAGGIANO NINETTA': ['138 ARNOLD ST'],
#  'FIGUEIRA FERNANDA S': ['138 ARNOLD ST'],
#  'NAPOLEAO CLAUDIOMAR': ['138 ARNOLD ST'],
#  'TORRA DAVID M': ['138 ARNOLD ST'],
#  'MRKALJ NADA': ['149 ARNOLD ST'],
#  'MRKALJ BOZO': ['149 ARNOLD ST'],
#  'RUBIO JOSE A': ['150 ARNOLD ST'],
#  'GARCIA-TORRES TERESA CARMEN': ['150 ARNOLD ST'],
#  'LOPEZ-GARCIA SARA E': ['150 ARNOLD ST'],
#  'LOPEZ GARCIA YESENIA E': ['150 ARNOLD ST'],
#  'GARCIA ANDREA VANESSA': ['150 ARNOLD ST'],
#  'KWONG MUNLAN': ['152 ARNOLD ST'],
#  'KWONG JOHN': ['152 ARNOLD ST'],
#  'KWONG SHIRLEY': ['152 ARNOLD ST'],
#  'KURSHUMI BESNIK': ['153 ARNOLD ST'],
#  'KURSHUMI ZAMIRA': ['153 ARNOLD ST'],
#  'SHIJAKU VILDAN': ['153 ARNOLD ST'],
#  'SHIJAKU SILVANA': ['153 ARNOLD ST'],
#  'SHIJAKU DARLI': ['153 ARNOLD ST'],
#  'SHIJAKU KEVIN': ['153 ARNOLD ST'],
#  'FISHER DAVID PAUL': ['154 ARNOLD ST'],
#  'HENNIS LAWRENCE P': ['154 ARNOLD ST'],
#  'NIKODINOVIC PERO': ['157 ARNOLD ST'],
#  'NIKODINOVIC DANICA': ['157 ARNOLD ST'],
#  'NIKODINOVIC BOJAN': ['157 ARNOLD ST'],
#  'ROY KEVIN A': ['161 ARNOLD ST'],
#  'DALTON TAMMY M': ['161 ARNOLD ST'],
#  'DALTON BRIAN G': ['161 ARNOLD ST'],
#  'MEIER ALEXANDRA PATRICIA': ['161 ARNOLD ST'],
#  'MACKEY JONATHAN': ['161 ARNOLD ST'],
#  'DALTON KRISTOPHER M': ['161 ARNOLD ST'],
#  'DALTON ROBERT ADAM': ['161 ARNOLD ST'],
#  'DEOLIVEIRA NAYARA G': ['166 ARNOLD ST'],
#  'VELEZ-TAMAYO JONATHAN': ['169 ARNOLD ST'],
#  'ALBANO PATRICIA': ['173 ARNOLD ST'],
#  'JANIAK CELIA A': ['174 ARNOLD ST'],
#  'OLSZEWSKI ROY P': ['174 ARNOLD ST'],
#  'PAWLAK JOANNA': ['176 ARNOLD ST'],
#  'MATARAZZO MARY': ['177 ARNOLD ST'],
#  'MUNIZ ARIEL': ['180 ARNOLD ST'],
#  'MUNIZ AMANDA L': ['180 ARNOLD ST'],
#  'ORTIZ JUSTIN': ['180 ARNOLD ST'],
#  'DEMARCO LINDA L': ['181 ARNOLD ST'],
#  'KRUSZEWSKI KACPER K': ['182 ARNOLD ST'],
#  'KRUSZEWSKI JANELLE A': ['182 ARNOLD ST'],
#  'RECUPERO THERESA V': ['187 ARNOLD ST'],
#  'PIERRE HANTZ': ['188 ARNOLD ST'],
#  'NOEL MARC': ['188 ARNOLD ST'],
#  'BENNETT DARYLN BEAUJOUR': ['188 ARNOLD ST'],
#  'BENNETT CARLA ANGEL': ['188 ARNOLD ST'],
#  'HECTOR FREDERICK R': ['193 ARNOLD ST'],
#  'HECTOR KAREN': ['193 ARNOLD ST'],
#  ...}

# %%
#data comparison: add the new mailing.bedroom.unit dataset
comp_names2 = []
num2 = 0
for row in df_mbu.itertuples():
#     print(row.Owner)
    if row.Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Owner]:
            comp_names2.append(row.Owner)
    if row.Second_Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Second_Owner]:
            comp_names2.append(row.Second_Owner)
    if row.Third_Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Third_Owner]:
            comp_names2.append(row.Third_Owner)

mm_owners = set(comp_names2)
print('names with different address new:',len(mm_owners))
print('names appear in both sheets new:',num2)
print('percent that a person have multiple properties:',len(mm_owners)/num2)
# Out:
# names with different address new: 655
# names appear in both sheets new: 3705
# percent that a person have multi properties: 0.1767881241565452

# %%
# Out:
# ['74 FRANCIS ST']
