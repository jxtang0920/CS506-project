# %%
import pandas as pd

# %% [markdown]
# ### Read datasets

# %%
#reading datasets
df_mailing = pd.read_excel('2 residential exemption mailing.xlsx', sheetname='Sheet1')
df_mailing = df_mailing.drop(columns=['Unnamed: 2','Unnamed: 9','Unnamed: 13'])
df_rk1 = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Assessors')
df_rk2 = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Resident List')
df_rk1.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_rk2.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_mailing.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
df_mismatch=[]
total0 = 0
for row in df_rk1.itertuples():
    if row.Address_Match == False:
        df_mismatch.append(row)
        total0 += 1
    if row.Address_Match == True:
        total0 += 1
df_mismatch = pd.DataFrame(df_mismatch)

# %% [markdown]
# ### data cleaning functions

# %%
#data cleaning
def upperletter(row):
    return row.str.upper()
def trimdata(row):
    return row.str.strip()
df_rk1[['Merged','Mailing_Address','Owner_1','Owner_2','Owner_3']] = df_rk1[['Merged','Mailing_Address','Owner_1','Owner_2','Owner_3']].apply(trimdata, axis=1).apply(upperletter, axis=1)
df_rk2[['Merged','Street_name','Name']] = df_rk2[['Merged','Street_name','Name']].apply(trimdata, axis=1).apply(upperletter, axis=1)
df_mailing = df_mailing.apply(trimdata, axis=1)

# %%
#mailing.bedroom.unit dataset
df_mbu = pd.read_excel('mailing.bedroom.unit.xlsx')
df_mbu.rename(columns=lambda x:x.replace(' ','_'), inplace=True)
df_mbu = df_mbu.drop(columns=['Unnamed:_2','Unnamed:_9','Unnamed:_13'])
df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']] = df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']].apply(trimdata, axis=1)
df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']] = df_mbu[['Mailing_Street_Address','Owner','Second_Owner','Third_Owner']].apply(upperletter, axis=1)

# %% [markdown]
# ### calculate address mismatch by mailing address

# %%
# print(df_rk1.shape)
# print(df_mismatch.shape)
# print(df_mismatch.columns)
# print(df_rk1.columns)
print("mailing mismatch percent:",df_mismatch.shape[0]/total0)
merged = set(df_rk2.Name)
df_extract = []
rv = 0
for row in df_rk1.itertuples():
    if row.Owner_1 in merged or row.Owner_2 in merged or row.Owner_3 in merged:
        df_extract.append(row)
    if row.Mailing_City == 'REVERE ':
        rv += 1
df_extract = pd.DataFrame(df_extract) 
rv
# Out:
# mailing mismatch percent: 0.26574181757767074
# 8965

# %%
#extract dataframe that address exist in both sheets.
merged2 = set(df_rk2.Merged)
tmp = []
for row in df_rk1.itertuples():
    if row.Merged in merged2 or row.Mailing_Address in merged2:
        tmp.append(row)
df_extract2 = pd.DataFrame(tmp)

# %%
#create a dict to store all the owners that have multiple properties based on df_rk2.
#create a list to store the owner names.
#or it may result in duplicate names.
addr_dict={}
multi_owner = []
multi = 0
for row in df_rk2.itertuples():
    Merged2 = str(row.House_number)+' '+row.Street_name
    if row.Name not in addr_dict:
        addr_dict[row.Name] = [Merged2]
    else:
        if [Merged2] == addr_dict[row.Name]:
            continue
        else:
            addr_dict[row.Name].append(Merged2)
            multi_owner.append(row.Name)

# %%
len(addr_dict)
# Out:
# 36609

# %%
#measure the percentage by person
comp_names = []
num = 0
all_addr = []
noop_addr = []
for row in df_rk1.itertuples():
    if row.Owner_1 in addr_dict or row.Owner_2 in addr_dict or row.Owner_3 in addr_dict:
        all_addr.append(row.Mailing_Address)
    if row.Owner_1 in addr_dict:
        num+=1
        if row.Mailing_Address not in addr_dict[row.Owner_1]:
            comp_names.append(row.Owner_1)
            noop_addr.append(row.Mailing_Address)
    if row.Owner_2 in addr_dict:
        num+=1
        if row.Mailing_Address not in addr_dict[row.Owner_2]:
            comp_names.append(row.Owner_2)
            noop_addr.append(row.Mailing_Address)
    if row.Owner_3 in addr_dict:
        num+=1
        if row.Mailing_Address not in addr_dict[row.Owner_3]:
            comp_names.append(row.Owner_3)
            noop_addr.append(row.Mailing_Address)
m_owners = set(comp_names)
all_addr = set(all_addr)
noop_addr = set(noop_addr)
print('names with different address:',len(m_owners))
print('names appear in both sheets:',num)
print('percent that a person have multiple properties:',len(m_owners)/num)
print(len(all_addr))
print(len(noop_addr))
print(len(noop_addr)/len(all_addr))
# Out:
# names with different address: 623
# names appear in both sheets: 4136
# percent that a person have multiple properties: 0.15062862669245647
# 3044
# 568
# 0.18659658344283836

# %%
#data comparison: add the new mailing.bedroom.unit dataset
comp_names2 = []
num2 = 0
noop_addr2 = []
for row in df_mbu.itertuples():
#     print(row.Owner)
    if row.Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Owner]:
            comp_names2.append(row.Owner)
            noop_addr2.append(row.Mailing_Street_Address)
    if row.Second_Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Second_Owner]:
            comp_names2.append(row.Second_Owner)
            noop_addr2.append(row.Mailing_Street_Address)
    if row.Third_Owner in addr_dict:
        num2+=1
        if row.Mailing_Street_Address not in addr_dict[row.Third_Owner]:
            comp_names2.append(row.Third_Owner)
            noop_addr2.append(row.Mailing_Street_Address)

mm_owners = set(comp_names2)
print('names with different address new:',len(mm_owners))
print('names appear in both sheets new:',num2)
print('percent that a person have multiple properties:',len(mm_owners)/num2)
noop_addr2 = set(noop_addr2)
print(len(noop_addr2))
# Out:
# names with different address new: 655
# names appear in both sheets new: 3705
# percent that a person have multiple properties: 0.1767881241565452
# 582

# %%
len((noop_addr2)&(noop_addr))
# Out:
# 423

# %%
len(noop_addr2)
# Out:
# 582

# %%
len(noop_addr|noop_addr2)
# Out:
# 727

# %%
noop_addr_merge = (noop_addr|noop_addr2)

# %%
len(noop_addr_merge)
# Out:
# 727

# %%
#### new methods

# %%
df_as = pd.read_excel('Modify_ASRL.xlsx', sheetname='Modify_AS')
df_rl = pd.read_excel('Modify_ASRL.xlsx', sheetname='Modify_RL')
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
sname_rl = []
name_rl = []
def trim2(row):
    return row.replace('-','')
df_rl['Sorted_Owner'].apply(trim2)
for row in df_rl.itertuples():
    sname_rl.append(row.Sorted_Owner)
    name_rl.append(row.Name)

# %%
sname_rl
name_rl
# Out:
# ['HORROCKS RUTH E',
#  'MACANCELA SONIA',
#  'MACANCELA JHONNY OSWALDO',
#  'SANTACRUZ KATHERINE JANETH',
#  'MACANCELA KELLY N',
#  'MACANCELA CRISTOPHER A',
#  'HERNANDEZ ROBERTO A',
#  'OCASIO SALVADORA',
#  'HERNANDEZ ROBERTO A',
#  'BARRETO EDMARIET',
#  'HERNANDEZ SONYA E',
#  'SAENZ JAMIE',
#  'SAENZ JUANCARLOS',
#  'SAENZ MARTHA L',
#  'BELMONTE DEBORAH',
#  'BELMONTE ANTHONY A',
#  'ELDEEB AMIR K',
#  'ABDOU NISRINE',
#  'ABDOU ILYASS',
#  'SOLEMINA REGIS R',
#  'PEREIRA MARCIO I',
#  'PEREIRA JUSSANE',
#  'OLIVEIRA CILEIMAR S',
#  'COUTINHO ISABEL O',
#  'SILVA GILSON',
#  'COUTINHO ALINE OLIVEIRA',
#  'SILVA JENNA S',
#  'VENTURA JAEDER',
#  'EBEJA ARMAND',
#  'POWERS DOLORES',
#  'AGUILAR MARLENY',
#  'VELASQUEZ ARIEL O',
#  'PERRETTI DOMENIC A',
#  'PERRETTI LORETTA',
#  'PERRETTI COREY J',
#  'ORREGO NEBARDO',
#  'SHELDON RICHARD W',
#  'ORREGO MALLORY',
#  'BERNARD LLEANNA G',
#  'WAPLE JENNIFER M',
#  'RIVERA HECTOR A',
#  'RIVERA SUSAN',
#  'CARSON ZACKARY RYAN',
#  'RIVERA ALEXANDER',
#  'ORTEZ ENNA R',
#  'GUTIERREZ DANIEL A',
#  'GUTIERREZ CECY',
#  'BRANGIFORTE NICOLAS M',
#  'GUTIERREZ LIZBETH',
#  'LE MINI HA',
#  'LE DEXTER',
#  'DION MICHELLE',
#  'DION CHRISTOPHER S',
#  'LUCIFORA TORI',
#  'CIOFFI PATRICIA J',
#  'FOTI SALVATORE P',
#  'CUSTOVIC ENVER',
#  'LYONS MARILYN C',
#  'WINER BRIAN',
#  'MEDEIROS DEBORAH ANN',
#  'FUSCO CLIFFORD',
#  'PUBLICOVER MAXINE A',
#  'QUEVEDO YOLANDA',
#  'DIRUZZA JOSEPH A',
#  'DIRUZZA JUDITH MARY',
#  'BAKHSISS TRACEY A',
#  'FLICKINGER ROSE',
#  'CONNORS TERRY-ANN',
#  'MUDGE RUTH B',
#  'BEL GRINI MOHAMED',
#  'CHAOUI MERYEM',
#  'COUNTIE EDMUND A',
#  'MARGARECI ANTHONY FRANK',
#  'FANTASIA ANGELA',
#  'THEALL GAIL P',
#  'FELIX AMYBETH',
#  'EL ARAYACHE RAHMA',
#  'LIMOLI ROBIN A',
#  'MARSTON BEATRICE',
#  'BERBERENA JORGE L',
#  'SANTANIELLO ELAINE D',
#  'PEACH JEAN',
#  'CHAU SANDY',
#  'BATISTA LILLIAN',
#  'MAK VONN',
#  'DZEKO SUAD',
#  'HAMDI NAIMA',
#  'MOHAMMED KHOUYA',
#  'GARCIA ORLANDO',
#  'DEGARCIA ARGENTINA',
#  'PROCHILO JOSEPH J',
#  'ABDULLA KAMAL QADIR',
#  'ABDULLA AMINA ALI',
#  'FALZONE LAURETTA',
#  'KEHAYOGLOU JOHN T',
#  'RIOS MARIA LOUDES',
#  'STAFFORD JUSTIN',
#  'HARLOW NANCY',
#  'AZZAOUI NADRA',
#  'HAKIMI ABDUL F',
#  'LAVINE ROBERT',
#  'PETRELLO CHERYL A',
#  'TIPPETT JENNIE ELAINE',
#  'BASTOS LEDA',
#  'LOPES LIDIA MARIA',
#  'MCCONNELL SARINA MARIE',
#  'BARNABY GLORIA',
#  'YEM SALIN',
#  'LUDOVICI RONALD A',
#  'GATTA JOSEPHINE',
#  'BAHRAOUI ELFATIMI',
#  'SAHAFI FRIHA',
#  'BIRD SHARON MARIE',
#  'DIBIASE MICHAEL P',
#  'CIRIELLO GAETANO',
#  'CIRIELLO DORA',
#  'CAFARELLI IDA',
#  'BRADSHAW RUPERT M',
#  'RICHARDSON WALTER',
#  'BRADSHAW GEORGINA',
#  'KING PATRICK ANTHONY',
#  'BELLE-KING CAROL J',
#  'BRADSHAW JAMARIE',
#  'CHALLENGER SHAMAR K',
#  'FOUNTAIN GINA E',
#  'FOUNTAIN NEAL H',
#  'GRIMALDI ADA M',
#  'RIVERA PABLO',
#  'GRIMALDI ADA C',
#  'MOSCATO ANDREW J',
#  'HESTER SEAN',
#  'RUDECINDO RAMON',
#  'RUDECINDO AURORA',
#  'RUDECINDO RAMON A',
#  'RUDECINDO PAOLA',
#  'RUDECINDO BRENDALISSE',
#  'RUDECINDO OSCAR',
#  'SENIBALDI NICOLE A',
#  'SENIBALDI MICHAEL E',
#  'SENIBALDI MARK S',
#  'MACALLISTER ANTHONY PAUL',
#  'MORALES DOLORES C',
#  'BLANCO FRANCISCO A',
#  'ZAVALA SAMUEL A',
#  'MORALES KATHERINE E',
#  'TEJADA IVAN W',
#  'SERRANO IRIS C',
#  'COPPOLA MARIE R',
#  'WILLIAMSON CHERYL A',
#  'WOODLAND GLORIA T',
#  'WOODLAND MICHAEL J',
#  'CRONIN JOANNE A',
#  'TEMPESTA BARBARA R',
#  'HECKLEY RICHARD O',
#  'HECKLEY LORIE J',
#  'HECKLEY SAMANTHA MARIE',
#  'VELAZQUEZ JOLERIE',
#  'BRUNO JULIA L',
#  'MARTIN SHAUNA JANINE',
#  'MCGAH DEBORAH',
#  'BOUHAJBANE SAID',
#  'HADIF HAYAT',
#  'TRONCOSO ISABEL',
#  'PENA T ISAMAR',
#  'DISISTO LYDIA J',
#  'SPAGNUOLO JESSICA L',
#  'DELIC BOJANA',
#  'MORICO PATRICIA',
#  'WEEKS JAMES LOUIS',
#  'BENINATI MARY R',
#  'FERRAGAMO JOAN R',
#  'DEVITO DEVON E',
#  'DEVITO SAMANTHA J',
#  'GIPSON CATHERINE M',
#  'SPAGNUOLO DIANA L',
#  'SPAGNUOLO LAWRENCE',
#  'SPAGNUOLO CHRISTINA',
#  'SPAGNUOLO DANIEL J',
#  'SPAGNUOLO MATTHEW',
#  'VALENTIN JOHN M',
#  'VALENTIN BRITTANY M',
#  'LYONS PAULINE M',
#  'ATTARDO DENISE M',
#  'GROCH KEVIN',
#  'TROCHEZ ELAINE E',
#  'VEERASAMMY VEERANGA S',
#  'AYAR SALAHEDDINE',
#  'VEERASAMMY CHRISTINA I',
#  'STANTON JACOB',
#  'BREA ARAMIS E',
#  'GORDON AMBER LEE',
#  'LOMBARD JAMES JOSEPH',
#  'MARCHANTE CHRISTIAN',
#  'ZELAYANDIA STEPHANIE B',
#  'ZELAYANDIA RENE ALBERTO',
#  'POJOY ALIDA L',
#  'ORELLANA KIMBERLY A',
#  'OCHOA DIEGO A',
#  'ROSCOE JANELLE MARIE',
#  'JONES ASHLEY MARIE',
#  'CORNWELL MARISSA L',
#  'NERIS NILDA',
#  'NERIS FRANCISCO',
#  'NERIS JOANNA',
#  'VASQUEZ AARON',
#  'AGUAOUZ ABDEL K',
#  'AGUAOUZ BOUCHRA',
#  'HARROUCHI AICHA',
#  'AGUAOUZ AMIRA S',
#  'ROSADO RAMON L',
#  'CERRATO DIMAS O',
#  'RIANI ASMAA',
#  'AITELHADJ TOURIYA',
#  'AGUILAR RAUL',
#  'LEMUS-AGUILAR GUMERCINDA',
#  'AVALOS CARLOS E',
#  'FABIAN-MARTIN JERONIMO',
#  'LONDONO JHON A',
#  'NO RODAS NORMA R',
#  'MUNETON ELIANA M',
#  'VETRANO NANCY R',
#  'SCAFATI JENNIFER L',
#  'DIGIANVITTORIO DANIEL J',
#  'NAPOLI VICTORIA ANN',
#  'RAMCHARAN ANCILLA',
#  'RAMCHARAN ALISTAIR JASON',
#  'RAMCHARAN ANDREW T',
#  'RAMCHARAN JENNIFER M',
#  'GUTIERREZ DANIEL A',
#  'VIANA KAROLINE C',
#  'VIANA WENDEL R',
#  'CORBELLE KACIE E',
#  'CORBELLE DONALD W',
#  'CORBELLE DEBORAH A',
#  'CORBELLE KELLI L',
#  'CORBELLE KARA MARIE',
#  'CORBELLE DONALD HENRY',
#  'TUSA ANTHONY P',
#  'GIANNETTA LORI',
#  'CIFUENTES ISAIAS',
#  'VELAZQUEZ JOSE',
#  'CIFUENTES MORENA',
#  'CIFUENTE-PINEDA JOSUE A',
#  'NAIM JILALI',
#  'EMBIRIK KHADDOUJAH',
#  'NAIM ABDELGHANI',
#  'ZAIDI KHADIJA',
#  'MESNAOUI DOHA',
#  'SAHROUR NOUREDINE',
#  'SAHROUR ASMAA AZIZI',
#  'SAHROUR OMAR SLEEMAN',
#  'DICENSO RONALD A',
#  'DICENSO GINA M',
#  'DICENSO DEREK C',
#  'DICENSO JAGGER C',
#  'DICENSO RAQUEL-ALEXA',
#  'SHALEMO SAMUEL T',
#  'BIRHAN NEKATIBEB',
#  'BATYDANG ABEBA',
#  'SILBURN FELIANN A',
#  'MORGAN DOROTHY PAGE',
#  'MORGAN MICHAEL A',
#  'VERRILL KAREN M',
#  'DESHAIES RICHARD',
#  'SILUE KOLOTIOLOMA',
#  'SILUE MEFONGA AWA',
#  'SAVANE MAGBE',
#  'ORILEY REGINA M',
#  'CORRADO ANGELINA A',
#  'MCDONALD SHARON M',
#  'WILLIS HELEN',
#  'MCDONALD PATRICK J',
#  'MAGUIRE MARY A',
#  'HARVEY SUZANNE JAYNE',
#  'VALENTINI GIOVANNA',
#  'BRITO ANANIAS G',
#  'BAPTISTA LAURA',
#  'VALENTINI-BRITO MARIA V',
#  'BRITO CHRISTIAN',
#  'BRITO BRENDON',
#  'GALVEZ MEDARDO',
#  'ARISMENDY LUZ E',
#  'BELCAID KHALIL',
#  'LAFONTAINE REINA JANETH',
#  'LAFONTAINE PIERRE D',
#  'AGUILERA AGUILAR CLAUDIO',
#  'OQUELI SKARLETH M',
#  'MARTINEZ MARLON H',
#  'MARTINEZ MEXULLAN',
#  'MCLAUGHLIN JENNIFER LYN',
#  'KIELPINSKI JESSIE M',
#  'BAMBERG ROBERT P',
#  'SISSON ROBIN M',
#  'BOSCO JOANNE B',
#  'BOSCO JOSHUA J',
#  'BOSCO JESSE BIRD',
#  'BOSCO JULIA ROSE',
#  'RONGA GLORIA',
#  'RONGA VANESSA',
#  'RONGA ERICA',
#  'PULISCIANO ALAN J',
#  'AUSTIN MARGARET',
#  'FEDOROVA SVETLANA',
#  'BOGUSLAVSKIY EVGUENI A',
#  'MUTCHLER TRENT P',
#  'QING-KEATING LILY',
#  'FARINELLA ROSS C',
#  'FARINELLA MELISSA A',
#  'BARMAKI LAMYAA S',
#  'ADAMS ELEANOR F',
#  'DIGIANNI JOSEPH J',
#  'RHODENIZER RACQUEL ANNE',
#  'SOLEMINA DAVID J',
#  'SOLEMINA LISA M',
#  'FIGUEROA DENISE',
#  'DEAGLE DEBRA A',
#  'CHRISTOPHER LAWRENCE J',
#  'CHRISTOPHER RACHEL H',
#  'CHRISTOPHER BRENDAN M',
#  'SIMS ROBERT JOSEPH',
#  'CALDEN JENNIFER MARIE',
#  'MOSCHELLA PATRICIA A',
#  'MOSCHELLA KEVIN C',
#  'CITINO RICHARD J',
#  'BEARDSLEY KENNETH MICHAEL',
#  'BEARDSLEY LINDA V',
#  'PERGOLA ROBIN A',
#  'CLARK BRENDA',
#  'PERGOLA JAMES M',
#  'PERGOLA PAIGE M',
#  'PERGOLA JAIDE M',
#  'PERGOLA MATTHEW M',
#  'FARRELL SHEILA R',
#  'EPSIMOS EDNA M',
#  'ESPARZA ADAN',
#  'BUENROSTRO SILVIA',
#  'ESPARZA ALANDRA',
#  'DUFF DIANNE',
#  'DUFF ASHLEY',
#  'DUFF BRITTANY L',
#  'PINEDA ABRAHAM A',
#  'NUFIO ELVA L',
#  'BRASSIL JAMES R',
#  'MCKAY SANDRA A',
#  'GLISERMAN GAIL C',
#  'STRINGI DAVID ANTHONY',
#  'MAGGIO MARGARET M',
#  'SANDERS REGINA',
#  'ALVARADO DELWIN A',
#  'ALVARADO DAZLEE A',
#  'FITZPATRICK CORNELIUS J',
#  'WATSON CAROL A',
#  'SABER ABDERRAHMANE',
#  'BONILLA ANA',
#  'HERNANDEZ JULIO E',
#  'HERNANDEZ ERIKA Y',
#  'COGGSWELL MARY',
#  'CHERRY JEFFREY RYNE',
#  'MELCHER ALEX J',
#  'ALARCON ISABEL',
#  'LEGUISAMON WALLIS M',
#  'MOJICA FREDDIE',
#  'PISATURO MASSIMINA',
#  'ZINAOUI FATIMA',
#  'EL ATRASSI SIDI BOUCHAIB',
#  'MOREIRA JEFFERSON S',
#  'MOREIRA CLAUDIA CRUZ',
#  'GOUVEIA JOSEPH',
#  'SINE MARY M',
#  'KASINOWICZ CHRISTINE M',
#  'CRUZ IRIS A',
#  'PEGUERO ELVIS J',
#  'SILVA RICHARD C',
#  'SILVA GARCIA BRENDA A',
#  'PEREZ TORRES JONATHAN',
#  'MEDINA RUIZ AGIE CAROLINA',
#  'GONZALES DIEGO A',
#  'MOYA MARIA ISABEL',
#  'OLIVA BETTINA C',
#  'MUNOZ CARLOS M',
#  'RODRIGUEZ MARIA',
#  'AMAYA CARLOS A',
#  'RODRIGUEZ MARIA A',
#  'ARGUETA OSCAR AGUIRRE',
#  'ARGUETA MAYRA',
#  'ARGUETA BRIAN A',
#  'ARGUETA OSCAR E',
#  'ARGUETA JOSELINE',
#  'TARASKIEWICZ ARLENE B',
#  'BERTOCCHI BENAE M',
#  'BERTOCCHI DANIEL J',
#  "D'EON MARIE L",
#  'WHITE ROBERT F',
#  'DIROCCO-MERRITT GINA',
#  'NICOSIA LORENZO',
#  'NICOSIA MAUREEN',
#  'PORTILLO GABRIEL',
#  'SCHEPICI-PORTILLO AMANDA JOY',
#  'NICOSIA MICHAEL L',
#  'VALDEZ JOSE J',
#  'VALLEJO SANDRA',
#  'MORADEL-DEMENCIA VICTORINA',
#  'MENCIA JACOB',
#  'MARGARY VALDEZ',
#  'HEGNER NICOLE',
#  'HEGNER NICHOLAS',
#  'WHITEHEAD CALVIN D',
#  'FRANCOIS-LETANG ROSE',
#  'LOUIS-JEAN MOUDLEY',
#  'LOUIS-JEAN ANGELE L',
#  'SPELLEN MARC ANTHONY',
#  'CROWLEY MATTHEW P',
#  'MEARA ROBERT M',
#  'FLYNN TERENCE J',
#  'FLYNN VIRGINIA A',
#  'BUCCI CHRISTOPHER A',
#  'DURBANO DIANA',
#  'FONSECA RODRIGO',
#  'FONSECA ROSA',
#  'FONSECA NORMA',
#  'LOPEZ JOSE R',
#  'GIANGREGORIO RAFFAELLA',
#  'IASBARRONE GEORGE W',
#  'IASBARRONE JUDITH A',
#  'IASBARRONE GEORGE',
#  'IASBARRONE DANIELLE L',
#  'IASBARRONE NANCY MAE',
#  'LINARES DELIA MARITZA',
#  'RECAREY JAIME',
#  'TORRES RONALD F',
#  'DELEON PEDRO PABLO',
#  'SASSO JACQUELINE A',
#  'GUARINO LAWRENCE J',
#  'SULLIVAN EDWARD S',
#  'PEREZ ISABEL M',
#  'OCHOA CARLOS H',
#  'MARTINEZ JULIO J',
#  'GUEVARA NOEMI C',
#  'MARTINEZ MADELIN N',
#  'MARTINEZ JAIME V',
#  'MARTINEZ JENNIFER',
#  'IACOVIELLO FRANK',
#  'IACOVIELLO SANDRA',
#  'IACOVELLO NATASHA',
#  'GILLEBERTO HELENA',
#  'LAWLEY KAREN L',
#  'VALDEZ HERNANDEZ ANDREA DEJESUS J',
#  'PEREZ DOMINGO A',
#  'LOPEZ ANTONIO O',
#  'GUZMAN DE LOPEZ MARIA E',
#  'SANCHEZ PEREZ ARIANNY R',
#  'MUNGUIA JOSE ABILIO',
#  'MUNGUIA JOSE A',
#  'DIAZ ANA M',
#  'HERNANDEZ ANA M',
#  'MUNGUIA DAVID A',
#  'CUSHING STEPHEN H',
#  'MORIGERATO NANCY L',
#  'CIULLA JESSE L',
#  'BROWN YVONNE E',
#  'FALZARANO LOUIS E',
#  'SILVA JANINE MARIE',
#  "D'AMATO NICOLE",
#  'FALZARANO TONI A',
#  'DEASY-BOCCHINO IRENE G',
#  'LAM THUAN N',
#  'LAM NGOCMAI',
#  'GRAY PATRICIA S',
#  'GRAY RITA M',
#  'FLEMMING BAYLEE G',
#  'VILLANUEVA MARVIN D',
#  'MARTINEZ DE VILLANUEVA ROSA I',
#  'RIVERA VANESSA',
#  'GOMEZ GRACE',
#  'DIAZ SUMAYA',
#  'MOLINA JIMMY J',
#  'VICENTE JO-ANN',
#  'MOLINA CARLOS X',
#  'COLON ROSALINA',
#  'CONCEPCION YANIRA MARIE',
#  'PACE MITCHELL',
#  'PACE KENNETH D',
#  'SPINA SAMUEL PETER',
#  'DOHERTY PETER A',
#  'ALVES MARIANY P',
#  'SOBRINHO FRANCISCO A',
#  'ALVES ALBA VP',
#  'ROCHA-SAAR MARCIA P',
#  'ALVES MARCOS',
#  'SPERA TERESA M',
#  'MEADOWCROFT MARC PETER',
#  'NORCOTT WILLIAM J',
#  'NORCOTT DEBORAH E',
#  'DEFRONZO MARINA',
#  'CARDONA JASON C',
#  'DZUZDANOVIC MUHAMED',
#  'AGUIRRE ASDRUBAL',
#  'LAGORIO CORINNE M',
#  'PASTORE LINDA D',
#  'SCOPPA SUSAN A',
#  'WELLS MICHAEL S',
#  'WELLS JOAN',
#  'WELLS MACKENZIE E',
#  'MORALES DORIS D',
#  'MATHER ELIZABETH VICTORIA',
#  'MORALES ANA C',
#  'MORALES ELIZABETH',
#  'SALAZAR CHRISTIAN SHAMIR',
#  'RODRIGUEZ LUIS J',
#  'CHEA SOPHEA',
#  'ROS SAMNANG',
#  'ROS MICHELLE ELYSE',
#  'CATALDO GENNARO L',
#  'CATALDO ROSETTE M',
#  'MAHARJAN BISHWO',
#  'MAHARJAN MIRA',
#  'ROSA ZINA MARIA',
#  'LACERDA QUEZIA R',
#  'LAURIA MARYLOU',
#  'LACIVITA NANCY L',
#  'MANISCALCO ACCURZIO',
#  'MANISCALCO JEANNINE C',
#  'LUSTENBERGER ANNETTE F',
#  'RISTINO JUDITH A',
#  'RISTINO JOSEPH JC',
#  'RISTINO JOSEPH G',
#  'FABIANO HOPE',
#  'PIZZANO ALFRED',
#  'PIZZANO ELAINE MARIE',
#  'HINOJOSA MICHAEL',
#  'HINOJOSA MARIEELENA',
#  'HINOJOSA CHRISTOPHER',
#  'HINOJOSA ALLY',
#  'CATALLO STEPHEN C',
#  'CATALLO LUCILLE M',
#  'LOPILATO MICHAEL A',
#  'LOPILATO ANTHONY F',
#  'LOPILATO MARILYN R',
#  'RUSSO CAROL A',
#  'PINI GERALD A',
#  'RUSSO JOAN M',
#  'MARINO JEAN C',
#  'RUSSO JOSEPHINE P',
#  'LOCHIATTO LOUISE',
#  'ROMANO DARIA L',
#  'ROMANO KURT C',
#  'ROMANO ALEXANDER K',
#  'SPEZIALE GINA',
#  'COHEN VALENTINA N',
#  'GORHAM MICHAEL F',
#  'GORHAM TANYA H',
#  'COHEN LEA',
#  'COHEN MONIQUE',
#  'CIANO CORINNE',
#  'CIANO ANTHONY',
#  'HEARD WENDELL R',
#  'KING ADRIAN S',
#  'WILLIAMS GAIL E',
#  'MARTIN DAVID J',
#  'MCALLISTER MARK',
#  'DEYANE NOUREDDINE',
#  'RAE AMY',
#  'SUAZO ALEX D',
#  'TRACY MICHAEL A',
#  'TRACY NANCY M',
#  'BOCCUZZI VITO F',
#  'MARTINEZ SERGIO',
#  'MENDEZ ESTER',
#  'PERAZA HERIBERTO',
#  'MESTANZA JOSE M',
#  'SUCHITE DE PERAZA EUFEMIA',
#  'MORAN MARTHA D',
#  'MESTANZA ZULMA A',
#  'MESTANZA ELSY N',
#  'SANCHEZ STEVEN ALEXANDER',
#  'MESTANZA-AGUILAR ZURIELLE A',
#  'MESTANZA-MORAN MARIO',
#  'MESTANZA-MORAN MARTHA E',
#  'FERULLO ANTHONY',
#  'DAVIS DIANA M',
#  'DAVIS MARGARET L',
#  'CORDWELL-RIZZO ROSALIE',
#  'MEJIA DENNIS',
#  'CERMINARA ANTHONY J',
#  'GUTIERREZ MIRSA ESTEFANY',
#  'BLANCO LEDY D',
#  'BLANCO KAREN T',
#  'GOMES SANDRA A',
#  'APARICIO ANA B',
#  'CHICAS CESAR A',
#  'OCHOA JOAO FABIO',
#  'CHICAS FERNANDA G',
#  'KATICA ALIJA',
#  'KATICA ADISA',
#  'OUAKANI LEKBIR',
#  'BOUBAKRAOUY SAMIRA',
#  'PAOLINI ANTHONY',
#  'BATES MADONNA L',
#  'QUEZADA DAVID E',
#  'LATTANZI CELESTE',
#  'COSCIA DONNA M',
#  'SCANELLI ROBERT',
#  'PFEIFER GERALDINE',
#  'PFEIFER CARLTON A',
#  'DESANTIS JAMES RICHARD',
#  'DESANTIS JOSEPH A',
#  'DESANTIS JOHN A',
#  'DESANTIS JENAE',
#  'FORNIA LYDIA',
#  'BIRD JOSEPH T',
#  'GRAVALLESE MICHAEL A',
#  'GRAVALLESE CATHERINE A',
#  'MACDONALD BRIAN J',
#  'GRAVALLESE LYN',
#  'FERNANDES ELEINE R',
#  'GREGORIO CELESTE',
#  'GREGORIO BRIANA',
#  'DELGRECO-FICHERA JEANINE M',
#  'FICHERA TIA LOREN',
#  'DESANTIS FRANCES M',
#  'CONSOLO LISA F',
#  'KRUSCHEWSKY LILIANA M',
#  'SULLIVAN PAUL L',
#  'MAZZOLA LAURA',
#  'CAPACHIETTI IDAJORON',
#  'HERNANDEZ JOSE I',
#  'HERNANDEZ YRANIA',
#  'LOUGHNER LIAM G',
#  'PUOPOLO ROBERT',
#  'SPONAGLE WILLIAM WAYNE',
#  'BOURZAK AICHA',
#  'BENAYAD CHAIMAA',
#  'KADDIOUI TOURIA',
#  'CHOURAK BOUCHAIB',
#  'RAMIREZ TRANSITO A',
#  'RUIZ SYLVIA',
#  'GRANITO NICHOLAS P',
#  'CHEESEMAN JOHN',
#  'SALIE JOHN H',
#  'WAREHAM JUNE M',
#  'OPUSTIL PAWEL J',
#  'LEWIS AVERY',
#  'WIXON CLARENCE M',
#  'WIXON DEBORAH',
#  'WIXON GAETANO N',
#  'FORD JESSI A',
#  'COLLAZO ANNIE M',
#  'RONDON MCCLELLAND C',
#  'RONDON LAUREN N',
#  'RONDON JOSHUA E',
#  'ALLEN JOSHUA D',
#  'OCONNOR ANDREW',
#  'AQUALANEY JENNIFER R',
#  'DASILVA TIANNA E',
#  'DESIMONE JOHNATHAN',
#  'RINALDI COREY R',
#  'TESTA MAUREEN E',
#  'TESTA JOSEPH A',
#  'LOMBARDO KALI A',
#  'PEREZ JOSE L',
#  'PEREZ ALIDA A',
#  'MACINNES CATHERINE ROSE',
#  'HOYSRADT PAMELA',
#  'ROSADO JON A',
#  'LONG AMMIE',
#  'LONG JACK',
#  'PEREZ JAZMIN A',
#  'LAWYER LESLIE J',
#  'GAUDIN CHRISTINA R',
#  'SCOTT JULIA M',
#  'HANSON DEBRA',
#  'COIMBRA EUDEVAN',
#  'MACHADO MARIA',
#  'MCGRORY ELLEN M',
#  'TOPPI SUSAN M',
#  'MCNAMARA DOROTHY',
#  'BENOIT RICHARD',
#  'OROZCO ENRIQUE G',
#  'DOLAN NANCY A',
#  'ROMERO MARCELINO',
#  'MERINO SOFIA',
#  'RAYMOND JUSTINE',
#  'ROMERO WILL A',
#  'LEVCHENKO BORIS',
#  'LEVCHENKO TATYANA',
#  'DELEARY RICHARD EARL',
#  'DELEARY ANNMARIE',
#  'WENTWORTH SALLY V',
#  'BROWN WENDY J',
#  'BROWN CHARLES E',
#  'ZENGA CHERYL CHRISTINE',
#  'ZENGA NICHOLAS M',
#  'ZOUHAIR DRISS',
#  'CHARLEBOIS JACQUELINE',
#  'BAOUSSOUH AZIZ',
#  'ZOUHAIR BOUCHRA',
#  'TAREK HAKINA',
#  'NEVEU RAYMOND P',
#  'NEVEU NICOLE M',
#  'CARDONA NELSON',
#  'SULLIVAN MAUREEN M',
#  'LANZA LORENA C',
#  'LANZA JOSEPH A',
#  'JOHNSON MARGARET A',
#  'PRIZIO CHERYL A',
#  'CRONIN STEPHEN NICHOLAS',
#  'ZIMMERMAN HUNTER A',
#  'SHKOZA PIRO',
#  'SHKOZA FLORIN',
#  'SHKOZA GERALD',
#  'SHKOZA ALVA',
#  'DESIMONE VICTOR',
#  'DESIMONE SHERI',
#  'DUARTE JOHN LENNON',
#  'CARRIERE BRITTANY M',
#  'STRELITZ ROBERT F',
#  'JENKINSON KATHRYN ANN',
#  'BRADLEY PAUL',
#  'BRADLEY BONNIE L',
#  'MAGANA JILLIAN A',
#  'MAGANA ARMANDO',
#  'RINALDI LISA',
#  'BURROW RODERICK R',
#  'RINALDI JOSEPH M',
#  'RINALDI AMBER E',
#  'DAO THANH VAN',
#  'PHAM HONG THI',
#  'SHAW DENNIS M',
#  'BRODERICK CHRISTINE L',
#  'MCMENAMIN DAVID J',
#  'HONOHAN JAMES J',
#  'HONOHAN MICHELE A',
#  'DEVEAU MELISSA R',
#  'HONOHAN JAMES J',
#  'ALCANTARA JULIO',
#  'ALCANTRA MARIA',
#  'GANOZA JOHNNY',
#  'SOLANO ESTRELLA',
#  'ALCANTARA EVELYN G',
#  'ALCANTARA GIANPIERE J',
#  'GANOZA NAHORY',
#  'LOPEZ MARIA J',
#  'LOPEZ JOSE A',
#  'LOPEZ RENE A',
#  'LOPEZ LUIS A',
#  'FLORES BELKI A',
#  'LOPEZ BERNARDO D',
#  'IRAHETA ROSA G',
#  'LOPEZ-IRAHETA ELIAS D',
#  'CHEN HAIXIONG',
#  'WU QINGHUA',
#  'HUIMING LI',
#  'LI DALING',
#  'CHEN AIZHEN',
#  'DANH PHON THI',
#  'DANH HANH',
#  'DANH HIEU MINH',
#  'DANH MYPHUNG',
#  'DANH PHUONG M',
#  'CHAU SANG',
#  'DIMARTINO PIETRINA',
#  'HOXHA LULZIM',
#  'HOXHA HYRIJE XIM',
#  'HOXHA AFRIM',
#  'PHAM BIEN CONG',
#  'PHAM ANNA',
#  'CORTAVE HECTOR O',
#  'SOLORZANO BRIAN J',
#  'CORTAVE KATHRYN M',
#  'LOPEZ YARIV',
#  'ARGUETA AGUIRRE JULIAN',
#  'ARGUETA AGUIRRE DILMA',
#  'REYES LOPEZ PEDRO',
#  'MEJIA-BETANCUR CRISTIAN O',
#  'KHOUBACH ELHACHM',
#  'AMGHAR KHADIJA',
#  'KHOUBACH RAJAA',
#  'KHOUBACH LATIFA',
#  'KHOUBACH IMANE',
#  'MORALES ANNETTE',
#  'LIMA MARIA',
#  'LIMA ANDREAS',
#  'WHITTAKER PAULA M',
#  'GRIECO CONCETTA',
#  'RUIZ NATALIA',
#  'RUIZ JULIAN',
#  'RUIZ LOPEZ KAREN',
#  'PEREZ LEONCIO ALBERTO',
#  'JARAMILLO OLGA CECILIA',
#  'PEREZ DIEGO LEON',
#  'PEREZ DAVID E',
#  'VILLADA KATHERINE',
#  'PEREZ JHON',
#  'MENDELSOHN JULIE',
#  'CROWE ROBERT JOSEPH',
#  'MAMBUCA MARILYN E',
#  'YAQOOB ROBYN L',
#  'YAQOOB MUHAMMAD',
#  'YAQOOB NYLA ELEANOR',
#  'YAQOOB ZEESHAN N',
#  'LAKACHA KRISTIN M',
#  'LAKACHA ELVIS',
#  'LAKACHA SELMA',
#  'LAKACHA AZRA',
#  'DAVIS ANGELA',
#  'DAVIS FRANCIS G',
#  'DAVIS HELEN M',
#  'RAMIREZ JOSE',
#  'HURTADO-KHODIR BLANCA M',
#  'KHODIR MOHAMED A',
#  'AYLWARD BERTHA',
#  'HURTADO NESTOR DAVID',
#  'HURTADO EDUARDO',
#  'CIAMPA MICHAEL J',
#  'CIAMPA BRENDA L',
#  'CIAMPA ANTHONY',
#  'MEDINA JORGE',
#  'MEDINA PAULA ANDREA',
#  'BONILLA MARIA ZULMA',
#  'HENAO JOHNNY A',
#  'ALCANTAR ANTONIO',
#  'BUENROSTRO NORMA',
#  'ALCANTAR LUIS',
#  'ALCANTAR ABEL',
#  'ALCANTAR EMILY',
#  'JIMENEZ JUAN C',
#  'CORREA ADRIANA M',
#  'JIMENEZ ANGIE S',
#  'JIMENEZ JUAN C',
#  'ROCHA JOSEPH H',
#  'CALDER CYNTHIA M',
#  'RUSSELL MASON',
#  'FELICE KELLY S',
#  'DUNKIN JAMES M',
#  'MONDELLO CARA',
#  'DIROSA WILLIAM N',
#  'DUNKIN MATTHEW M',
#  'RANDAZZO KYLE R',
#  'MESA JOAQUIN',
#  'FERNANDEZ V LORENA D',
#  'CARDONA LAURA',
#  'TESTA JOSEPH J',
#  'YEPEZ DIEGO',
#  'ERAZO MARYURY',
#  'YEPEZ DIEGO',
#  'YEPEZ ESTEBAN',
#  'ERAZO HAROL L',
#  'ERAZO ALBA L',
#  'TREJOS STEPHANNY',
#  'ARBOLEDA NATHALIA',
#  'CARDONA DIEGO M',
#  'CROSBY LYNNEA ANN',
#  'CARNEY DONNA A',
#  'DUNPHY SHAUN P',
#  'DUNPHY ERIN A',
#  'CARBONE PETER M',
#  'CARBONE PAULA',
#  'AZIZEDDINE MOHAMED',
#  'AZIZEDDINE BADRE',
#  'AZIZEDDINE MOUNA',
#  'LYONS JAYME LYNN',
#  'BENITEZ ALFARO SILVIA JEANNETTE',
#  'PACHECO SANTOS GIOVANNI ALEXANDER',
#  'PETROZZELLI ANTHONY',
#  'PETROZZELLI JUDITH',
#  'PETROZZELLI JAMES P',
#  'PETROZZELLI HAYLEY N',
#  'PEDRO MARYELLEN',
#  'MCCARRON JAMES J',
#  'MCCARRON ROBIN M',
#  'MCCARRON KAYLA A',
#  'MCCARRON JAMES MICHAEL',
#  'AGUILAR JUAN A',
#  'CARBAJALES MARIA',
#  'RIVAS NANCY',
#  'CURRAN JOHN J',
#  'CURRAN JAMES H',
#  'GAUDET ANNETTE M',
#  'ZOLA JOSEPH P',
#  'CIMINO ANTONIO',
#  'CIMINO MARIE ROBIN',
#  'PITRONE ADRIANA MARIE',
#  'PITRONE JEFFREY NICHOLAS',
#  'CIMINO ALANDRIA C',
#  'CIMINO ANGELICA',
#  'KELTER V RICHARD',
#  'HOGAN BRIANNA ALEXIS',
#  'GRAHAM DANIEL R',
#  'ANDERSON GAIL M',
#  'ANDERSON TYLER R',
#  'ANDERSON GRACE ASHLEY',
#  'ANDERSON JUSTIN ALEXANDER',
#  'REYES ELMER L',
#  'DIAZ MARIA A',
#  'ACOSTA WILLIAM E',
#  'DIAZ LINDA M',
#  'RICHMAN CARLA M',
#  'ALBANESE SABINO',
#  'ALBANESE MARGHERITA',
#  'MONTERO EVERARDO',
#  'MONTERO FELICITA',
#  'MONTERO GRACE C',
#  'DEMELO ADINILSON',
#  'DEMELO ROSIANE N',
#  'RHOADES DEBRA B',
#  'EBERHARDT SHAWN M',
#  'EBERHARDT KATIE LYN',
#  'PINTO BEVERLY F',
#  'PINTO JAMES R',
#  'PINTO JAMIE R',
#  'DEMASI THERESA J',
#  'DEMASI JOHN P',
#  'KING DENISE M',
#  'THEODORE LOUIS P',
#  'STDIC YVETTE',
#  'THEODORE DAFNEY',
#  'RODRIGUEZ TOMAS',
#  'RODRIGUEZ ELBA',
#  'FOX JAMES L',
#  'THOMAS-FOX MARTINE A',
#  'RICHARDS MARINA R',
#  'PESCE MICHAEL A',
#  'PESCE CARMELLA N',
#  'FRANIS ABDERRAHIM',
#  'SAID FATIMA',
#  'TERRON MARIA L',
#  'PANZINI ROBIN M',
#  'PANZINI MATTHEW',
#  'PANZINI CHRISTOPHER M',
#  'FOLGORE PASQUALE',
#  'FOLGORE ROSELLA',
#  'LALLY MARIANNE',
#  'DEMINIE DIANE M',
#  'FERNANDEZ MICHELLE RUBY',
#  'DEMINIE PATRICIA R',
#  'DEMINIE JOHN PAUL',
#  'BARRY KASSANDRA',
#  'DEMINIE JENNA M',
#  'CANON LUZ M',
#  'LOKRITI FAKHREDDINE',
#  'TENTAS GEORGIA',
#  'SANTOSTEFANO JOANNE',
#  'DIGIULIO DEBRA A',
#  'DIGIULIO BENJAMIN PETER',
#  'REYES ANA A',
#  'REGA MARILU H',
#  'REGA JAN H',
#  'VILLAJULCA FELIPE A',
#  'EGE THOMAS J',
#  'EGE ANNMARIE',
#  'TRICKETT SUSAN',
#  'CAMPOS CARLOS O',
#  'BURGESS LAURA L',
#  'TORRA-CAGGIANO NINETTA',
#  'FIGUEIRA FERNANDA S',
#  'NAPOLEAO CLAUDIOMAR',
#  'TORRA DAVID M',
#  'MRKALJ NADA',
#  'MRKALJ BOZO',
#  'RUBIO JOSE A',
#  'GARCIA-TORRES TERESA CARMEN',
#  'LOPEZ-GARCIA SARA E',
#  'LOPEZ GARCIA YESENIA E',
#  'GARCIA ANDREA VANESSA',
#  'KWONG MUNLAN',
#  'KWONG JOHN',
#  'KWONG SHIRLEY',
#  'KURSHUMI BESNIK',
#  'KURSHUMI ZAMIRA',
#  'SHIJAKU VILDAN',
#  'SHIJAKU SILVANA',
#  'SHIJAKU DARLI',
#  'SHIJAKU KEVIN',
#  'FISHER DAVID PAUL',
#  'HENNIS LAWRENCE P',
#  'NIKODINOVIC PERO',
#  'NIKODINOVIC DANICA',
#  'NIKODINOVIC BOJAN',
#  'ROY KEVIN A',
#  'DALTON TAMMY M',
#  'DALTON BRIAN G',
#  'MEIER ALEXANDRA PATRICIA',
#  'MACKEY JONATHAN',
#  'DALTON KRISTOPHER M',
#  'DALTON ROBERT ADAM',
#  'DEOLIVEIRA NAYARA G',
#  'VELEZ-TAMAYO JONATHAN',
#  'ALBANO PATRICIA',
#  'JANIAK CELIA A',
#  'OLSZEWSKI ROY P',
#  'PAWLAK JOANNA',
#  'MATARAZZO MARY',
#  'MUNIZ ARIEL',
#  'MUNIZ AMANDA L',
#  'ORTIZ JUSTIN',
#  'DEMARCO LINDA L',
#  'KRUSZEWSKI KACPER K',
#  'KRUSZEWSKI JANELLE A',
#  'RECUPERO THERESA V',
#  'PIERRE HANTZ',
#  ...]

# %%
sname_as = []
name_as = []
for row in df_as.itertuples():
    for i in row.Sorted_Owner:
        pass
        #print(i)
        #sname_as.append(names)
    name_as.append(row.Owner_1)
    name_as.append(row.Owner_2)
    name_as.append(row.Owner_3)
