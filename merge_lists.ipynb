# %%
import pandas as pd
import csv
l1 = pd.read_csv('values_without_unit.csv', index_col=0)
l1
# Out:
#              address      2007      2008      2009      2010      2011  \
# 0             1 A ST  202200.0  211400.0  186400.0  162300.0  148200.0
# 1      11 ABRUZZI ST  431600.0  478600.0  433000.0  283600.0  271000.0
# 2      15 ABRUZZI ST  301300.0  320500.0  290100.0  247100.0  227800.0
# 3      19 ABRUZZI ST  313400.0  355800.0  312300.0  269900.0  251200.0
# 4      29 ABRUZZI ST  451800.0  442500.0  404200.0  353600.0  331700.0
# 5      30 ABRUZZI ST  268900.0  324600.0  302000.0  261900.0  244100.0
# 6      37 ABRUZZI ST  398900.0  409200.0  366300.0  320900.0  299900.0
# 7      42 ABRUZZI ST  281500.0  326300.0  289800.0  237600.0  220900.0
# 8      43 ABRUZZI ST  429800.0  432500.0  389100.0  287000.0  274400.0
# 9      52 ABRUZZI ST  284200.0  324800.0  288600.0  252500.0  234400.0
# 10     64 ABRUZZI ST  372100.0  377300.0  338600.0  258300.0  245600.0
# 11     65 ABRUZZI ST  283200.0  303500.0  277500.0  241000.0  223300.0
# ...

# %%
l2 = pd.read_csv('add_oo_lng_lat.csv', index_col=0)
l2
# Out:
#                     address  owner_occupied  longitude   latitude
# 0          89 LANCASTER AVE           False -70.964655  42.439249
# 1            17 SHIRLEY AVE            True -70.999751  42.409135
# 2            53 GOODWIN AVE            True -70.967520  42.437260
# 3              19 GENEVA ST           False -71.021106  42.425551
# 4               48 DERBY RD            True -71.016231  42.424494
# 5              97 CREST AVE            True -70.988138  42.396841
# 6              37 AVALON ST           False -70.992689  42.404296
# 7                 95 BAY RD            True -70.988191  42.420913
# 8            79 WOODLAND RD            True -70.987523  42.427790
# 9             200 CREST AVE            True -70.984754  42.395423
# 10             9 AMBROSE ST            True -71.008012  42.415932
# 11             18 JARVIS ST            True -71.024217  42.413851
# 12            90 WHITIN AVE           False -70.964084  42.439929
# ...

# %%
l3 = pd.merge(l1, l2, on='address')
l3
# Out:
#              address           2007           2008           2009  \
# 0             1 A ST  202200.000000  211400.000000  186400.000000
# 1      11 ABRUZZI ST  431600.000000  478600.000000  433000.000000
# 2      15 ABRUZZI ST  301300.000000  320500.000000  290100.000000
# 3      19 ABRUZZI ST  313400.000000  355800.000000  312300.000000
# 4      29 ABRUZZI ST  451800.000000  442500.000000  404200.000000
# 5      30 ABRUZZI ST  268900.000000  324600.000000  302000.000000
# 6      37 ABRUZZI ST  398900.000000  409200.000000  366300.000000
# 7      42 ABRUZZI ST  281500.000000  326300.000000  289800.000000
# 8      43 ABRUZZI ST  429800.000000  432500.000000  389100.000000
# 9      52 ABRUZZI ST  284200.000000  324800.000000  288600.000000
# 10     65 ABRUZZI ST  283200.000000  303500.000000  277500.000000
# 11     68 ABRUZZI ST  472800.000000  469700.000000  424300.000000
# 12     69 ABRUZZI ST  285100.000000  302300.000000  276200.000000
# ...

# %%
l3.to_csv('values_location.csv')
