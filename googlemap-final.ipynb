# %%
import pandas as pd
import csv
address = pd.read_csv('owner_occupied_add5.csv', index_col=0)
address
# Out:
#                     address  owner_occupied
# 0          89 LANCASTER AVE           False
# 1            17 SHIRLEY AVE            True
# 2            53 GOODWIN AVE            True
# 3              19 GENEVA ST           False
# 4               48 DERBY RD            True
# 5              97 CREST AVE            True
# 6              37 AVALON ST           False
# 7                 95 BAY RD            True
# 8            79 WOODLAND RD            True
# 9             200 CREST AVE            True
# 10             9 AMBROSE ST            True
# 11             18 JARVIS ST            True
# 12            90 WHITIN AVE           False
# 13            12 EVERARD ST            True
# 14           1 ATLANTIC AVE            True
# 15     47 AURELIA SYLVIA DR           False
# 16       62 SOUTH IRVING ST           False
# 17          10 JEFFERSON DR            True
# 18              235 VANE ST           False
# 19             26 SEWALL ST           False
# ...

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyBH6Z0lvEOGtgLCrT0rwSqautdBSiLlhBs')

geocoding = pd.DataFrame(columns = ['address', 'owner_occupied', 'longitude', 'latitude'])

addlist = list(address['address'])
oolist = list(address['owner_occupied'])
for i in range(len(addlist)):
    # Geocoding an address
    add = addlist[i]
    geocode_result = gmaps.geocode(add + ', Revere, MA')
    try:
        loc = geocode_result[0]['geometry']['location']
        geocoding = geocoding.append({'address': add, 'owner_occupied': oolist[i], 'longitude': loc['lng'], 'latitude': loc['lat'], }, ignore_index=True)
    except:
        print('Request error.')
geocoding
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\Program Files\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# D:\Program Files\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
len(geocoding)
# Out:
# 5990

# %%
for i in range(5990, 8808):
    # Geocoding an address
    add = addlist[i]
    geocode_result = gmaps.geocode(add + ', Revere, MA')
    try:
        loc = geocode_result[0]['geometry']['location']
        geocoding = geocoding.append({'address': add, 'owner_occupied': oolist[i], 'longitude': loc['lng'], 'latitude': loc['lat'], }, ignore_index=True)
    except:
        print('Request error.')
geocoding
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-187904396c57> in <module>()
#       1 for i in range(5990, 8808):
#       2     # Geocoding an address
# ----> 3     add = addlist[i]
#       4     geocode_result = gmaps.geocode(add + ', Revere, MA')
#       5     try:
#
# IndexError: list index out of range

# %%
len(geocoding)
# Out:
# 8807

# %%
geocoding.to_csv('add_oo_lng_lat.csv')
