# %%
import pandas as pd
df_assessors = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Assessors')
df_assessors
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#      Owners           Parcel ID Street Number              Street Unit Number  \
# NaN     NaN            1-12-24            33           PEARL AVE
# NaN     NaN          23-352-39           404       RESERVOIR AVE
# NaN     NaN           21-340-9            36            FENNO ST
# NaN     NaN         26-430E-20            85           GENEVA ST
# NaN     NaN         27-439Q-20            58           SQUIRE RD
# NaN     NaN          10-182-18            80          CALUMET ST
# NaN     NaN          22-383-31            12          FURNESS ST
# NaN     NaN      10-189-22A-9C           350   REVERE BEACH BLVD          9C
# NaN     NaN           7-212-3B           590   REVERE BEACH PKWY
# NaN     NaN            8-129-6            60         THORNTON ST
# ...

# %%
df_resident_list = pd.read_excel('4 All Residential data_rk.xlsx', sheetname='Resident List')
df_resident_list
# Out:
# /Users/jxtang/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#                                Name  House number Suffix  Street name  \
# 0                   HORROCKS RUTH E             1     NaN        A ST
# 1                  MACANCELA SONIA             11     NaN  ABRUZZI ST
# 2          MACANCELA JHONNY OSWALDO            11     NaN  ABRUZZI ST
# 3        SANTACRUZ KATHERINE JANETH            11     NaN  ABRUZZI ST
# 4                 MACANCELA KELLY N            11     NaN  ABRUZZI ST
# 5            MACANCELA CRISTOPHER A            11     NaN  ABRUZZI ST
# 6               HERNANDEZ ROBERTO A            11     NaN  ABRUZZI ST
# 7                 OCASIO SALVADORA             11     NaN  ABRUZZI ST
# 8               HERNANDEZ ROBERTO A            11     NaN  ABRUZZI ST
# 9                 BARRETO EDMARIET             11     NaN  ABRUZZI ST
# ...

# %%
oo = {}
rl = {}
for row in df_resident_list.itertuples():
    add = row.Merged.strip()
    name = row.Name.strip()
    if add in oo.keys():
        oo[add].append(name)
    else:
        oo[add] = [name]
oo
# Out:
# {'1 A ST': ['HORROCKS RUTH E'],
#  '11 ABRUZZI ST 1': ['MACANCELA SONIA',
#   'MACANCELA JHONNY OSWALDO',
#   'SANTACRUZ KATHERINE JANETH',
#   'MACANCELA KELLY N',
#   'MACANCELA CRISTOPHER A'],
#  '11 ABRUZZI ST 2': ['HERNANDEZ ROBERTO A',
#   'OCASIO SALVADORA',
#   'HERNANDEZ ROBERTO A',
#   'BARRETO EDMARIET',
#   'HERNANDEZ SONYA E'],
#  '13 ABRUZZI ST': ['SAENZ JAMIE'],
#  '15 ABRUZZI ST': ['SAENZ JUANCARLOS', 'SAENZ MARTHA L'],
#  '19 ABRUZZI ST': ['BELMONTE DEBORAH', 'BELMONTE ANTHONY A'],
#  '29 ABRUZZI ST': ['ELDEEB AMIR K', 'ABDOU NISRINE', 'ABDOU ILYASS'],
#  '30 ABRUZZI ST': ['SOLEMINA REGIS R'],
#  '37 ABRUZZI ST 1': ['PEREIRA MARCIO I', 'PEREIRA JUSSANE'],
#  '37 ABRUZZI ST': ['OLIVEIRA CILEIMAR S',
#   'COUTINHO ISABEL O',
#   'SILVA GILSON',
#   'COUTINHO ALINE OLIVEIRA',
#   'SILVA JENNA S',
#   'VENTURA JAEDER'],
#  '42 ABRUZZI ST': ['EBEJA ARMAND'],
#  '43 ABRUZZI ST 2': ['POWERS DOLORES'],
#  '52 ABRUZZI ST': ['AGUILAR MARLENY', 'VELASQUEZ ARIEL O'],
# ...

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyBH6Z0lvEOGtgLCrT0rwSqautdBSiLlhBs')

geocoding = pd.DataFrame(columns = ['longitude', 'latitude', 'address'])
for add in oo.keys():
    # Geocoding an address
    geocode_result = gmaps.geocode(add + ', Revere, MA')
    try:
        loc = geocode_result[0]['geometry']['location']
        geocoding = geocoding.append({'longitude': loc['lng'], 'latitude': loc['lat'], 'address': add}, ignore_index=True)
    except:
        print('Request error.')
geocoding
# Out:
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.
# Request error.

# %%
ge1 = geocoding

# %%
keys = list(oo.keys())[1155:]

for add in keys:
    # Geocoding an address
    geocode_result = gmaps.geocode(add + ', Revere, MA')
    try:
        loc = geocode_result[0]['geometry']['location']
        geocoding = geocoding.append({'longitude': loc['lng'], 'latitude': loc['lat'], 'address': add}, ignore_index=True)
    except:
        print('Request error.')
geocoding
# Out:
# Request error.
# Request error.
# Request error.

# %%
writer = pd.ExcelWriter('output.xlsx')
geocoding.to_excel(writer,'Sheet1')
writer.save()
